# %%
from bs4 import BeautifulSoup
import requests

# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# Importar librerías para procesamiento de texto
# -----------------------------------------------------------------------
import re

# %%
url_wikipedia = "https://es.wikipedia.org/wiki/Premios_%C3%93scar"

res_wikipedia = requests.get(url_wikipedia)

print(f"La respuesta de la petición es", res_wikipedia.status_code)

#dentro del for, poner un if que si respuesta es diferente a 200, intentar otro enlace
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 url_wikipedia = "https://es.wikipedia.org/wiki/Premios_%C3%93scar"
# ----> 3 res_wikipedia = requests.get(url_wikipedia)
#       5 print(f"La respuesta de la petición es", res_wikipedia.status_code)
#       7 #dentro del for, poner un if que si respuesta es diferente a 200, intentar otro enlace
#
# File /usr/lib/python3/dist-packages/requests/api.py:76, in get(url, params, **kwargs)
#      65 r"""Sends a GET request.
#      66
#      67 :param url: URL for the new :class:`Request` object.
#    (...)
#      72 :rtype: requests.Response
#      73 """
#      75 kwargs.setdefault('allow_redirects', True)
# ---> 76 return request('get', url, params=params, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:544, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     539 send_kwargs = {
#     540     'timeout': timeout,
#     541     'allow_redirects': allow_redirects,
#     542 }
#     543 send_kwargs.update(settings)
# --> 544 resp = self.send(prep, **send_kwargs)
#     546 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:657, in Session.send(self, request, **kwargs)
#     654 start = preferred_clock()
#     656 # Send the request
# --> 657 r = adapter.send(request, **kwargs)
#     659 # Total elapsed time of the request (approximately)
#     660 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:700, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697     self._prepare_proxy(conn)
#     699 # Make the request on the httplib connection object.
# --> 700 httplib_response = self._make_request(
#     701     conn,
#     702     method,
#     703     url,
#     704     timeout=timeout_obj,
#     705     body=body,
#     706     headers=headers,
#     707     chunked=chunked,
#     708 )
#     710 # If we're going to release the connection in ``finally:``, then
#     711 # the response doesn't need to know about the connection. Otherwise
#     712 # it will also try to release it and we'll have a double-release
#     713 # mess.
#     714 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:383, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381 # Trigger any extra validation we need to do.
#     382 try:
# --> 383     self._validate_conn(conn)
#     384 except (SocketTimeout, BaseSSLError) as e:
#     385     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     386     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:1017, in HTTPSConnectionPool._validate_conn(self, conn)
#    1015 # Force connect early to allow us to validate the connection.
#    1016 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1017     conn.connect()
#    1019 if not conn.is_verified:
#    1020     warnings.warn(
#    1021         (
#    1022             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1027         InsecureRequestWarning,
#    1028     )
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:353, in HTTPSConnection.connect(self)
#     351 def connect(self):
#     352     # Add certificate verification
# --> 353     conn = self._new_conn()
#     354     hostname = self.host
#     355     tls_in_tls = False
#
# File /usr/lib/python3/dist-packages/urllib3/connection.py:169, in HTTPConnection._new_conn(self)
#     166     extra_kw["socket_options"] = self.socket_options
#     168 try:
# --> 169     conn = connection.create_connection(
#     170         (self._dns_host, self.port), self.timeout, **extra_kw
#     171     )
#     173 except SocketTimeout:
#     174     raise ConnectTimeoutError(
#     175         self,
#     176         "Connection to %s timed out. (connect timeout=%s)"
#     177         % (self.host, self.timeout),
#     178     )
#
# File /usr/lib/python3/dist-packages/urllib3/util/connection.py:86, in create_connection(address, timeout, source_address, socket_options)
#      84     if source_address:
#      85         sock.bind(source_address)
# ---> 86     sock.connect(sa)
#      87     return sock
#      89 except socket.error as e:
#
# KeyboardInterrupt:

# %%
sopa_peliculas = BeautifulSoup(res_wikipedia.content, "html.parser")

print(sopa_peliculas.prettify())

# %%
tabla = sopa_peliculas.findAll("table")
tabla[2]

# %%
mi_tabla = tabla[2]

lineas = mi_tabla.find_all("tr")
len(lineas)
# Out:
# 97

# %%
mi_tabla = tabla[2]

heather = mi_tabla.find_all("th")
len(heather)
# Out:
# 10

# %%
mi_tabla = tabla[2]

columnas = mi_tabla.find_all("td")
len(columnas)
# Out:
# 929

# %%
resultados = []

for fila in lineas[83:]:
    columnas = fila.find_all("td")

    # verifico que tengas las buenas cantidades de columnas
    if len(columnas) >= 5:

        print(columnas[1])
        fecha = columnas[1].text.strip()
        fecha2 = fecha.split
        mejor_pelicula = columnas[2].text.strip()
        mejor_director = columnas[3].text.strip()
        mejor_actor = columnas[4].text.strip()
        mejor_actriz = columnas[5].text.strip()

        resultados.append((fecha, mejor_pelicula, mejor_director, mejor_actor, mejor_actriz))

# Imprimo simplemente para asegurarme que este bien
for resultado in resultados:
    print(resultado)

# %%
columnas_df = ["Fecha", "Mejor Película", "Mejor Director", "Mejor Actor", "Mejor Actriz"]
df_oscars = pd.DataFrame(resultados, columns=columnas_df)

# %%
df_oscars
# Out:
#                    Fecha                                   Mejor Película  \
# 0   27 de febrerode 2011                                The King's Speech
# 1   26 de febrerode 2012                                       The Artist
# 2   24 de febrerode 2013                                             Argo
# 3      2 de marzode 2014                                 12 Years a Slave
# 4   22 de febrerode 2015  Birdman or (The Unexpected Virtue of Ignorance)
# 5   28 de febrerode 2016                                        Spotlight
# 6   26 de febrerode 2017                                        Moonlight
# 7      4 de marzode 2018                               The Shape of Water
# 8   24 de febrerode 2019                                       Green Book
# 9    9 de febrerode 2020                                         Parasite
# 10    25 de abrilde 2021                                        Nomadland
# 11    27 de marzode 2022                                             CODA
# 12    12 de marzode 2023                Everything Everywhere All at Once
# 13    10 de marzode 2024                                      Oppenheimer
#
#                                        Mejor Director  \
# 0                        T. Hooper(The King's Speech)
# 1                         M. Hazanavicius(The Artist)
# 2                                  A. Lee(Life of Pi)
# 3                                  A. Cuarón(Gravity)
# 4   A. G. Iñárritu(Birdman or (The Unexpected Virt...
# 5                        A. G. Iñárritu(The Revenant)
# 6                             D. Chazelle(La La Land)
# 7                     G. del Toro(The Shape of Water)
# 8                                     A. Cuarón(Roma)
# 9                                   Bong J.(Parasite)
# 10                                 C. Zhao(Nomadland)
# 11                   J. Campion(The Power of the Dog)
# 12  D. Kwan D. Scheinert(Everything Everywhere All...
# 13                              C. Nolan(Oppenheimer)
#
#                               Mejor Actor  \
# 0             C. Firth(The King's Speech)
# 1                 J. Dujardin(The Artist)
# 2                   D. Day-Lewis(Lincoln)
# 3      M. McConaughey(Dallas Buyers Club)
# 4   E. Redmayne(The Theory Of Everything)
# 5               L. DiCaprio(The Revenant)
# 6       C. Affleck(Manchester by the Sea)
# 7                 G. Oldman(Darkest Hour)
# 8             R. Malek(Bohemian Rhapsody)
# 9                       J. Phoenix(Joker)
# 10                 A. Hopkins(The Father)
# 11                 W. Smith(King Richard)
# 12                   B. Fraser(The Whale)
# 13                 C. Murphy(Oppenheimer)
#
#                                          Mejor Actriz
# 0                              N. Portman(Black Swan)
# 1                            M. Streep(The Iron Lady)
# 2                J. Lawrence(Silver Linings Playbook)
# 3                          C. Blanchett(Blue Jasmine)
# 4                                J.Moore(Still Alice)
# 5                                     B. Larson(Room)
# 6                                E. Stone(La La Land)
# 7   F. McDormand(Three Billboards Outside Ebbing, ...
# 8                              O. Colman(La favorita)
# 9                                  R. Zellweger(Judy)
# 10                            F. McDormand(Nomadland)
# 11                J. Chastain(The Eyes of Tammy Faye)
# 12         M. Yeoh(Everything Everywhere All at Once)
# 13                              E. Stone(Poor Things)

# %%
def extraer_oscars(url_wikipedia):
    res_wikipedia = requests.get(url_wikipedia)
    
    if res_wikipedia.status_code != 200:
        raise Exception (f"El código del error es :{res_wikipedia.status_code}")
    
    sopa_peliculas = BeautifulSoup(res_wikipedia.content, "html.parser")
    tablas = sopa_peliculas.findAll("table")

    mi_tabla = tablas[2]

    lineas = mi_tabla.findAll("tr")

    resultados = []

    for fila in lineas[83:]:
        columnas = fila.findAll("td")
        
        if len(columnas) >= 5:
            
            fecha = columnas[1].text.strip()
            fecha_limpia = re.sub(r"\s+", " ", fecha)  #
            fecha_limpia = re.sub(r"(\w+)(de)", r"\1 de", fecha_limpia) 
            mejor_pelicula = columnas[2].text.strip()
            mejor_director = columnas[3].text.strip()
            mejor_actor = columnas[4].text.strip()
            mejor_actriz = columnas[5].text.strip()

            resultados.append((fecha_limpia, mejor_pelicula, mejor_director, mejor_actor, mejor_actriz))

    columnas_df = ["Fecha", "Mejor Película", "Mejor Director", "Mejor Actor", "Mejor Actriz"]
    df_oscars = pd.DataFrame(resultados, columns=columnas_df)

    return df_oscars

# %%
url_wikipedia = "https://es.wikipedia.org/wiki/Premios_%C3%93scar"

# %%
df_oscars = extraer_oscars(url_wikipedia)

# %%
df_oscars
# Out:
#                     Fecha                                   Mejor Película  \
# 0   27 de febrero de 2011                                The King's Speech
# 1   26 de febrero de 2012                                       The Artist
# 2   24 de febrero de 2013                                             Argo
# 3      2 de marzo de 2014                                 12 Years a Slave
# 4   22 de febrero de 2015  Birdman or (The Unexpected Virtue of Ignorance)
# 5   28 de febrero de 2016                                        Spotlight
# 6   26 de febrero de 2017                                        Moonlight
# 7      4 de marzo de 2018                               The Shape of Water
# 8   24 de febrero de 2019                                       Green Book
# 9    9 de febrero de 2020                                         Parasite
# 10    25 de abril de 2021                                        Nomadland
# 11    27 de marzo de 2022                                             CODA
# 12    12 de marzo de 2023                Everything Everywhere All at Once
# 13    10 de marzo de 2024                                      Oppenheimer
#
#                                        Mejor Director  \
# 0                        T. Hooper(The King's Speech)
# 1                         M. Hazanavicius(The Artist)
# 2                                  A. Lee(Life of Pi)
# 3                                  A. Cuarón(Gravity)
# 4   A. G. Iñárritu(Birdman or (The Unexpected Virt...
# 5                        A. G. Iñárritu(The Revenant)
# 6                             D. Chazelle(La La Land)
# 7                     G. del Toro(The Shape of Water)
# 8                                     A. Cuarón(Roma)
# 9                                   Bong J.(Parasite)
# 10                                 C. Zhao(Nomadland)
# 11                   J. Campion(The Power of the Dog)
# 12  D. Kwan D. Scheinert(Everything Everywhere All...
# 13                              C. Nolan(Oppenheimer)
#
#                               Mejor Actor  \
# 0             C. Firth(The King's Speech)
# 1                 J. Dujardin(The Artist)
# 2                   D. Day-Lewis(Lincoln)
# 3      M. McConaughey(Dallas Buyers Club)
# 4   E. Redmayne(The Theory Of Everything)
# 5               L. DiCaprio(The Revenant)
# 6       C. Affleck(Manchester by the Sea)
# 7                 G. Oldman(Darkest Hour)
# 8             R. Malek(Bohemian Rhapsody)
# 9                       J. Phoenix(Joker)
# 10                 A. Hopkins(The Father)
# 11                 W. Smith(King Richard)
# 12                   B. Fraser(The Whale)
# 13                 C. Murphy(Oppenheimer)
#
#                                          Mejor Actriz
# 0                              N. Portman(Black Swan)
# 1                            M. Streep(The Iron Lady)
# 2                J. Lawrence(Silver Linings Playbook)
# 3                          C. Blanchett(Blue Jasmine)
# 4                                J.Moore(Still Alice)
# 5                                     B. Larson(Room)
# 6                                E. Stone(La La Land)
# 7   F. McDormand(Three Billboards Outside Ebbing, ...
# 8                              O. Colman(La favorita)
# 9                                  R. Zellweger(Judy)
# 10                            F. McDormand(Nomadland)
# 11                J. Chastain(The Eyes of Tammy Faye)
# 12         M. Yeoh(Everything Everywhere All at Once)
# 13                              E. Stone(Poor Things)
