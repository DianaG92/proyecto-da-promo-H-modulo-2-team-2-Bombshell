# %%
#Importar librerías para tratamiento de datos
import pandas as pd  # Pandas es una poderosa librería para manipulación y análisis de datos en Python.

# Importar librerías para web scraping y manipulación de datos
from bs4 import BeautifulSoup

# Importar librerías para automatización de navegadores web con Selenium
from selenium import webdriver  # Selenium es una herramienta para automatizar la interacción con navegadores web.
from webdriver_manager.chrome import ChromeDriverManager  # ChromeDriverManager gestiona la instalación del controlador de Chrome.
from selenium.webdriver.common.keys import Keys  # Keys es útil para simular eventos de teclado en Selenium.
from selenium.webdriver.support.ui import Select  # Select se utiliza para interactuar con elementos <select> en páginas web.

# Importar librerías para pausar la ejecución
from time import sleep  # Sleep se utiliza para pausar la ejecución del programa por un número de segundos.

import os
import signal
import sys
# Configuraciones
import re
pd.set_option('display.max_columns', None)  # Establece una opción de Pandas para mostrar todas las columnas de un DataFrame.

from selenium.common.exceptions import NoSuchElementException

# %%
#Creamos una función para poder ir guardando la info en caso de interrupción 
def signal_handler(signal, frame, driver, datos_peliculas):
    print("Proceso interrumpido. Guardando datos...")
    df_resultados_iniciales = pd.DataFrame(datos_peliculas)
    df_resultados_iniciales.to_csv('datos_iniciales.csv', index=False)
    print("Datos guardados en 'datos_iniciales.csv'.")
    guardar_datos(datos_peliculas)  #  definir esta función
    driver.close()
    sys.exit(0)
    
def guardar_datos(datos_peliculas):
   # Definimos el  archivo donde vamos a guardar los datos.
    ruta_archivo = 'fase-3-datos-actorxs-.csv'
    
    # Convertimos el diccionario a DataFrame
    df_nuevos_datos = pd.DataFrame(datos_peliculas)
    
    if os.path.exists(ruta_archivo):
        # Si el archivo ya existe, cargamos los datos existentes y los juntamos.
        df_existentes = pd.read_csv(ruta_archivo)
        df_resultante = pd.concat([df_existentes, df_nuevos_datos], ignore_index=True)
    else:
        # Si el archivo no existe, utiliza los nuevos datos directamente
        df_resultante = df_nuevos_datos
    
    # Guardamos el DataFrame resultante en el archivo, sobrescribiendo el archivo existente
    df_resultante.to_csv(ruta_archivo, index=False)
    
    print(f"Datos guardados o actualizados exitosamente en {ruta_archivo}.")

#definimos una función de try y except para los xpath, busca los datos con el xpath y si no lo encuentra, añade "N/A"
def get_data(driver,xpath): 
    try:
        data = driver.find_element("xpath", xpath).text
    except:
        data = "N/A"
    return data

#Creamos la función de extración de datos de los actores
def extraer_datos_actores(nombre_archivo): 

    df_pelis = pd.read_csv(nombre_archivo) #Extraemos la info de las películas de IMDb y nos quedamos con el ID de cada una

    df_pelis["ID de la Película"] = df_pelis["ID de la Película"].astype(str) #Igualamos los ID para que sean todos strings
    #Creamos una lista vacía
    datos_actores_total = []
    
    driver = webdriver.Chrome() #abrimos el chrome
    driver.maximize_window() #Lo maximizamos

    signal.signal(signal.SIGINT, lambda sig, frame: signal_handler(sig, frame, driver, datos_peliculas))  #Esto es para poder interrumpir la función.

    for id_imdb in df_pelis["ID de la Película"][801:1000]: #Iteramos sobre los ID de cada película
        try:
            url = f"https://www.imdb.com/title/{id_imdb}/" #cargamos la página de IMDb en Chrome
            driver.get(url)

            sleep(2)
            try:
                driver.find_element(
                    "xpath", '//*[@id="__next"]/div/div/div[2]/div/button[2]').click() #aceptamos las cookies
            except NoSuchElementException:
                pass

            sleep(2)  
            #hacemos clic en "reparto y equipo"
            driver.find_element("xpath", '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[1]/div/div[2]/ul/li[1]/a').click() 

            sleep(2)

            lista_actores = [] #creamos un listado vacío dentro del bucle para guardar la info

            # Buscamos todos los actores de la película
            actores = driver.find_elements(
                'class name', 'cast_list')[0].find_elements('tag name', 'tr')
            
            # aquí contamos cuántos actores hay en la lista. Le restamos 1 porque el primer elemento es el encabezado de la tabla y no tiene datos.
            numero_maximo_actores = 10 if len(
                actores)-1 > 10 else len(actores)-1

            #sacamos el nombre de la película
            nombre_peli = get_data(driver, '//*[@id="main"]/div[1]/div[1]/div/div[1]/h3/a') 

            for i in range(2, numero_maximo_actores): #Iteramos para extraer la info de los primeros 10 actores
                try:

                    sleep(2)
                     # Hacemos clic en el enlace del actor/actriz para que nos lleve a su página
                    driver.find_element("xpath", f'//*[@id="fullcredits_content"]/table[3]/tbody/tr[{i}]/td[2]/a').click()
                    sleep(3) 
                    #Cogemos su nombre
                    nombre_actxr = get_data(driver, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div/h1/span') #Extraemos nombre actor/actrix

                    #Extraemos las películas por las que estos actores son conocidos
                    conocido_por1 = get_data(driver, '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/div[2]/section[1]/div[2]/div/div[2]/div[1]/div[2]/div[1]/a')

                    conocido_por2 = get_data(driver, '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/div[2]/section[1]/div[2]/div/div[2]/div[2]/div[2]/div[1]/a')
                    conocido_por = [
                        conocido_por1, conocido_por2] if conocido_por2 != "N/A" else [conocido_por1]

                    # Extraemos la fecha de nacimiento haciendo un slicing para coger simplemente el año de nacimiento, y manejamos la excepción: de no ser un año poner N/A
                    fecha_nacimiento = get_data(
                        driver, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[3]/div/div[2]/section/aside/div/span[2]')
                    year_nacimiento = fecha_nacimiento.split(
                        " ")[-1:][0] if fecha_nacimiento != "N/A" else "N/A"

                    # Extraemos las profesiones del actor y moldeamos el texto para que si tiene más de una, aparezcan separadas por comas.
                    profesiones = get_data(
                        driver, '//*[@id="__next"]/main/div/section[1]/section/div[3]/section/section/div[2]/div/ul')
                    profesiones_string = ", ".join(
                        profesiones.split("\n")) if profesiones != "N/A" else "N/A"

                    # Cogemos los premios del actor, si es que tiene
                    premios = get_data(
                        driver, '//*[@id="__next"]/main/div/section[1]/div/section/div/div[1]/section[2]/div/ul/li/div/ul/li/span')
                    
                    #añadimos todos los datos extraídos a nuestra lista vacia
                    info_actores = (nombre_peli, nombre_actxr, conocido_por, #añadimos todos los datos extraídos a nuestra lista vacia
                                    year_nacimiento, profesiones_string, premios)
                    lista_actores.append(info_actores)
                    
                #Manejamos la excepción si no hay 10 actores o no encuentra alguno, para que nos diga cuál ha sido
                except NoSuchElementException:
                    print(f"\033[95mNo se encontró el actor número {i-1}\033[0m") 
                    pass

                finally:
                    driver.back() #volvemos para atrás para ir al siguiente actor

            print("Datos de los actores:")
            print(lista_actores)
            #Fuera del bucle, añadimos la lista con la info de cada actor/actriz a la lista con toda la información.
            datos_actores_total.extend(lista_actores)
        except Exception as e:
            print(f"Error al procesor la película {nombre_peli} con ID de IMDb {id_imdb}: {e}") #En caso de que no haya podido sacar datos de actores, que nos diga de que pelicula
    
    #Cerramos el driver
    driver.quit()
    #Le decimos que nos devuelva totos los datos de los actores.
    return datos_actores_total

# %%
#Leemos el csv con todas las peliculas, que contiene sus ID´s de IMDB
df_peliculas = pd.read_csv("peliculas_api.csv")

# %%
# Llamamos a  la función con nuestro archivo de pelis que sacamos de la API.
extraccion = extraer_datos_actores("peliculas_api.csv")
# Out:
# Datos de los actores:
# []
# No se encontró el actor número 7
# No se encontró el actor número 8
# Datos de los actores:
# [('Redemption', 'Derek Burke', ['Redemption', 'Reversion'], 'N/A', 'Reparto', 'N/A'), ('Redemption', 'July Smith', ['Redemption', 'A Fire in a Dovecot'], 'N/A', 'Reparto', 'N/A'), ('Redemption', 'Adam Chambers', ['Skylar contra el monstruo', 'I <3 Vampires'], '1983', 'Reparto, Dirección, Producción', '3 premios y 2 nominaciones'), ('Redemption', 'Shaina Vorspan', ['Dollface', 'Morir de pie'], 'junio', 'Reparto, Guion, Dirección', '1 premio y 1 nominación'), ('Redemption', 'Marco Neves', ['4 Horsemen: Apocalypse', 'Redemption'], 'N/A', 'Reparto, Equipos adicionales', '1,76 m'), ('Redemption', 'Aníbal Silveyra', ['Generation P', 'El año de la Marmota'], 'N/A', 'Reparto, Dirección', 'Malena')]
# Datos de los actores:
# []
# Datos de los actores:
# [('Final Level', 'Oneira Acosta', ['Final Level'], 'N/A', 'Reparto', 'N/A'), ('Final Level', 'Kelly Adames', ['Final Level'], 'N/A', 'Reparto', 'N/A'), ('Final Level', 'Matt Augenstein', ['Final Level'], 'N/A', 'Reparto', 'N/A'), ('Final Level', 'Guile Branco', ['Sistema Bruto', 'Coração de Cowboy'], 'junio', 'Reparto, Producción, Guion', '1 premio y 1 nominación'), ('Final Level', 'Wayne Chang', ['The Farewell', 'Megaman'], 'N/A', 'Dirección de casting, Reparto, Casting', 'N/A'), ('Final Level', 'Karina Colon', ['The Maybelline Girls', 'Vatos Locos'], 'N/A', 'Reparto, Producción, Dirección', 'N/A'), ('Final Level', 'Angela Diaz', ['Final Level', 'InSearchOf'], 'N/A', 'Reparto', 'N/A'), ('Final Level', 'Sarah Loren Gerber', ['Final Level'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('The Bad Penny', 'Casey T. Evans', ['Hired Gun', 'The Bad Penny'], '1974', 'Reparto, Producción, Guion', 'N/A'), ('The Bad Penny', 'Tom Arnold', ['Mentiras arriesgadas', 'La familia stupid'], '1959', 'Reparto, Producción, Guion', '5 premios y 3 nominaciones'), ('The Bad Penny', 'Nick Faltas', ['La sombra del reino', 'Over There'], 'N/A', 'Reparto', 'N/A'), ('The Bad Penny', 'Bai Ling', ['El laberinto rojo', 'El cuervo'], 'octubre', 'Reparto, Dirección, Producción', '20 premios y 7 nominaciones'), ('The Bad Penny', 'Josh Randall', ['Quarry', 'Ozark'], '1972', 'Reparto, Guion', 'N/A'), ('The Bad Penny', 'Lara Phillips', ['Camino a la perdición', 'El ala oeste de la Casa Blanca'], 'N/A', 'Reparto', 'N/A'), ('The Bad Penny', 'Ilia Volok', ['Géminis', 'Misión: Imposible - Protocolo fantasma'], '1964', 'Reparto, Equipos adicionales, Guion', '1 premio y 1 nominación'), ('The Bad Penny', 'Travis Aaron Wade', ['La guerra de los mundos', 'El falsificador'], '1975', 'Reparto, Producción, Guion', 'N/A')]
# Datos de los actores:
# [('The Girl with No Number', 'Bebe Pham', ['Trung so', 'Tolerancia cero'], 'N/A', 'Reparto, Producción', '1 premio'), ('The Girl with No Number', 'Jay Laisne', ['A Mormon President', 'The Hallway'], 'N/A', 'Reparto, Producción, Guion', 'N/A'), ('The Girl with No Number', 'Elina Madison', ['#LWL Laugh with Lillian', "Last Call at Murray's"], 'septiembre', 'Reparto, Producción, Guion', '10 premios y 1 nominación'), ('The Girl with No Number', 'Adrienne Ugarte', ['The Girl with No Number'], 'N/A', 'Reparto', 'N/A'), ('The Girl with No Number', 'Luong The Thanh', ['Tia Oi Ma Dia', 'Había una vez'], 'N/A', 'Reparto, Banda sonora', 'N/A'), ('The Girl with No Number', 'Nguyen Thi Cieu Xuan', ['The Girl with No Number', 'Ente gut!'], 'N/A', 'Reparto', 'N/A'), ('The Girl with No Number', 'Kersten Hui', ['Deep Gold', 'The Girl with No Number'], 'N/A', 'Reparto', 'N/A'), ('The Girl with No Number', 'Clint Jung', ['Jobs', 'Cam'], '2021', 'Reparto, Producción, Dirección', 'N/A')]
# Datos de los actores:
# [('The Honey Killer', 'Peter Cadwell', ["The Fighter's Ballad"], 'N/A', 'Reparto, Guion, Producción', '9 premios'), ('The Honey Killer', 'Ruben Crow', ['Mutual Friends', 'Caught'], 'N/A', 'Reparto', 'N/A'), ('The Honey Killer', 'Antonio Marascal Perez', ['The Honey Killer'], 'N/A', 'Reparto', 'N/A'), ('The Honey Killer', 'Marcus Petre', ['I Against I', 'The Honey Killer'], 'N/A', 'Cámara y electricidad, Reparto', 'N/A'), ('The Honey Killer', 'David Powell', ['The Conundrum', 'Fast Lane to Eden'], 'N/A', 'Reparto, Guion', 'N/A')]
# No se encontró el actor número 1
# No se encontró el actor número 2
# Datos de los actores:
# []
# Datos de los actores:
# [('Naughty @ 40', 'Govinda', ['Coolie No. 1', 'Partner'], '1963', 'Reparto, Música, Producción', '17 premios y 43 nominaciones'), ('Naughty @ 40', 'Yuvika Chaudhary', ['Om Shanti Om', 'Daddy Cool Munde Fool'], '1983', 'Reparto', '1 premio y 2 nominaciones'), ('Naughty @ 40', 'Anupam Kher', ['Hotel Bombay', 'The Accidental Prime Minister'], '1955', 'Reparto, Producción, Música', 'N/A'), ('Naughty @ 40', 'Smita Jaykar', ['Devdas', 'Sarfarosh'], 'N/A', 'Reparto', '2 nominaciones'), ('Naughty @ 40', 'Lucia Edwards', ['Transporter: La serie', 'Terra X - Rätsel alter Weltkulturen'], 'N/A', 'Reparto, Producción, Dirección', 'N/A'), ('Naughty @ 40', 'Sanjay Mishra', ['Masaan', 'Ankhon Dekhi'], '1963', 'Reparto, Cámara y electricidad, Composición', '12 premios y 30 nominaciones'), ('Naughty @ 40', 'Shakti Kapoor', ['Andaz Apna Apna', 'Gunda'], '1952', 'Reparto, Música, Banda sonora', '1 premio y 4 nominaciones'), ('Naughty @ 40', 'Harish', ['Gaddaar', 'Kaash... Hamara Dil Pagal Na Hota'], '1975', 'Reparto, Producción', 'Master Hari')]
# Datos de los actores:
# [('Chatur Singh Two Star', 'Sanjay Dutt', ['Munna Bhai M.B.B.S.', 'Lage Raho Munna Bhai'], '1959', 'Reparto, Música, Producción', '26 premios y 62 nominaciones'), ('Chatur Singh Two Star', 'Ameesha Patel', ['Reencuentro con el destino', 'Gadar: Ek Prem Katha'], '1975', 'Reparto, Producción', '8 premios y 18 nominaciones'), ('Chatur Singh Two Star', 'Anupam Kher', ['Hotel Bombay', 'The Accidental Prime Minister'], '1955', 'Reparto, Producción, Música', 'N/A'), ('Chatur Singh Two Star', 'Satish Kaushik', ['Tere Naam', 'Kaagaz'], '1956', 'Reparto, Dirección, Producción', '6 premios y 8 nominaciones'), ('Chatur Singh Two Star', 'Shakti Kapoor', ['Andaz Apna Apna', 'Gunda'], '1952', 'Reparto, Música, Banda sonora', '1 premio y 4 nominaciones'), ('Chatur Singh Two Star', 'Suresh Menon', ['Fanaa', 'Kaabil'], '1967', 'Reparto', '1 nominación'), ('Chatur Singh Two Star', 'Rati Agnihotri', ['Ek Duuje Ke Liye', 'Rakta Bandhan'], '1960', 'Reparto', '2 premios y 2 nominaciones'), ('Chatur Singh Two Star', 'Gulshan Grover', ['Badman', 'Mowgli y Baloo'], '1955', 'Reparto, Música', '5 premios y 7 nominaciones')]
# Datos de los actores:
# [('Qasos', 'Khashim Arslanov', ['Probuzhdenie', 'Otamdan qolgan dalalar'], '1956', 'Reparto', 'N/A'), ('Qasos', 'Gulchehra Eshonqulova', ["So'nggi lahza", 'Fotima va Zuxra'], 'N/A', 'Reparto', 'N/A'), ('Qasos', 'Furkat Fayziyev', ['Igra na vyzhivanie', 'Na krayu stoyu'], '1968', 'Reparto, Dirección de la segunda unidad o asistencia a dirección', 'Furkat Faiziyev'), ('Qasos', 'Seydulla Moldakhanov', ['Zolotoy zapas', 'Kinoplyonka No.8'], '1958', 'Reparto', 'S. Moldakhanov'), ('Qasos', 'Ubaydulo Omon', ['Fotima va Zuxra', "Qalb ko'zi"], 'N/A', 'Reparto', 'N/A'), ('Qasos', "Ulug'bek Qodirov", ['Er Bermoq - Jon Bermoq', 'Baron'], '1983', 'Reparto', 'N/A'), ('Qasos', 'Murad Radzhabov', ['Akademiya', 'Ulfatlar Tailandda'], '1949', 'Reparto, Dirección, Guion', 'N/A'), ('Qasos', 'Bekzod Tojiyev', ['I am not a terrorist', 'Sevgi fazosi'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Sex and Zen Extreme Ecstasy', 'Hiro Hayama', ['Million Loves in Me', 'New Police Story'], '1974', 'Reparto', '3 premios y 1 nominación'), ('Sex and Zen Extreme Ecstasy', 'Leni Lan Crazybarby', ['Taiping Gongzhu mi shi', 'Potseluy babochki'], '1990', 'Reparto', 'N/A'), ('Sex and Zen Extreme Ecstasy', 'Miyavi Matsunoi', ['Venus in Eros', 'Garo: Red Requiem'], '1988', 'Reparto', 'N/A'), ('Sex and Zen Extreme Ecstasy', 'Vienna Lyn', ['Mang nam gwan sei dui', 'Sex and Zen Extreme Ecstasy'], 'N/A', 'Reparto', 'N/A'), ('Sex and Zen Extreme Ecstasy', 'Yukiko Suô', ['Hotetoru-jô: Etsuraku torokenyû', 'Aka x Pinku'], '1988', 'Reparto', 'N/A'), ('Sex and Zen Extreme Ecstasy', 'Vonnie Lui', ['Hak sai lik', 'Shou shen'], 'N/A', 'Reparto', 'N/A'), ('Sex and Zen Extreme Ecstasy', 'Tony Ho', ['Juego sucio', 'New Police Story'], '1964', 'Reparto, Equipos adicionales', '1 nominación'), ('Sex and Zen Extreme Ecstasy', 'Kirt Kishita', ['Ghost in the Shell: El alma de la máquina', "Le Mans '66"], 'N/A', 'Reparto', 'N/A')]
# No se encontró el actor número 1
# No se encontró el actor número 2
# Datos de los actores:
# [('Chargesheet', 'Miyavi Matsunoi', ['Venus in Eros', 'Garo: Red Requiem'], '1988', 'Reparto', 'N/A'), ('Chargesheet', 'Vienna Lyn', ['Mang nam gwan sei dui', 'Sex and Zen Extreme Ecstasy'], 'N/A', 'Reparto', 'N/A'), ('Chargesheet', 'Yukiko Suô', ['Hotetoru-jô: Etsuraku torokenyû', 'Aka x Pinku'], '1988', 'Reparto', 'N/A'), ('Chargesheet', 'Vonnie Lui', ['Hak sai lik', 'Shou shen'], 'N/A', 'Reparto', 'N/A'), ('Chargesheet', 'Tony Ho', ['Juego sucio', 'New Police Story'], '1964', 'Reparto, Equipos adicionales', '1 nominación'), ('Chargesheet', 'Kirt Kishita', ['Ghost in the Shell: El alma de la máquina', "Le Mans '66"], 'N/A', 'Reparto', 'N/A')]
# No se encontró el actor número 1
# No se encontró el actor número 2
# Datos de los actores:
# [('Ogul', 'Miyavi Matsunoi', ['Venus in Eros', 'Garo: Red Requiem'], '1988', 'Reparto', 'N/A'), ('Ogul', 'Vienna Lyn', ['Mang nam gwan sei dui', 'Sex and Zen Extreme Ecstasy'], 'N/A', 'Reparto', 'N/A'), ('Ogul', 'Yukiko Suô', ['Hotetoru-jô: Etsuraku torokenyû', 'Aka x Pinku'], '1988', 'Reparto', 'N/A'), ('Ogul', 'Vonnie Lui', ['Hak sai lik', 'Shou shen'], 'N/A', 'Reparto', 'N/A'), ('Ogul', 'Tony Ho', ['Juego sucio', 'New Police Story'], '1964', 'Reparto, Equipos adicionales', '1 nominación'), ('Ogul', 'Kirt Kishita', ['Ghost in the Shell: El alma de la máquina', "Le Mans '66"], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Kako su me ukrali Nemci', 'Jelena Djokic', ['Kako su me ukrali Nemci', 'Crna svadba'], '1977', 'Reparto', 'N/A'), ('Kako su me ukrali Nemci', 'Douglas Henshall', ['Shetland', 'Invasión jurásica'], '1965', 'Reparto, Producción', '1 premio y 3 nominaciones'), ('Kako su me ukrali Nemci', 'Svetozar Cvetkovic', ['Turneja', 'You go to my head'], '1958', 'Reparto, Producción', 'N/A'), ('Kako su me ukrali Nemci', 'Dara Dzokic', ['U zatvoru', 'Tajne vinove loze'], '1955', 'Reparto', 'N/A'), ('Kako su me ukrali Nemci', "Miodrag 'Miki' Krstovic", ['La zona muerta', 'Uno tras otro'], '1950', 'Reparto', 'N/A'), ('Kako su me ukrali Nemci', "Vojislav 'Voja' Brajovic", ['Turneja', 'Turneja'], '1949', 'Reparto', 'N/A'), ('Kako su me ukrali Nemci', 'Gordan Kicic', ['Realna prica', 'Mama i tata se igraju rata'], '1977', 'Reparto, Guion, Producción', 'N/A'), ('Kako su me ukrali Nemci', 'Boris Isakovic', ['Quo vadis, Aida?', 'Last Christmas'], '1966', 'Reparto', '1 premio y 1 nominación')]
# Datos de los actores:
# [('Duet ming gam', 'Ching Wan Lau', ['Black Mask', 'Mad detective'], '1964', 'Reparto, Banda sonora', '13 premios y 41 nominaciones'), ('Duet ming gam', 'Richie Jen', ['Xing yuan', 'Foh lung'], '1966', 'Reparto, Dirección, Guion', '2 premios y 3 nominaciones'), ('Duet ming gam', 'Denise Ho', ['Duet ming gam', 'Yau lung hei fung'], '1977', 'Reparto, Producción', '1 premio y 6 nominaciones'), ('Duet ming gam', 'Myolie Wu', ['Na nian hua kai yue zheng yuan', 'Fei tin hei see'], '1979', 'Reparto, Banda sonora', '4 premios y 2 nominaciones'), ('Duet ming gam', 'Hoi-Pang Lo', ['The Grandmaster', 'Duet ming gam'], '1941', 'Reparto, Banda sonora', '2 premios y 3 nominaciones'), ('Duet ming gam', 'Hang-Shuen So', ['Duet ming gam', 'Una bala en la cabeza'], '1951', 'Reparto', 'Su Hsing-hsuan'), ('Duet ming gam', 'Philip Keung', ['Onda expansiva: Shock Wave', 'Fan zui xian chang'], '1966', 'Reparto, Producción', '1 premio y 7 nominaciones'), ('Duet ming gam', 'Eddie Cheung', ['Blackhat: Amenaza en la red', 'Yau doh lung fu bong'], '1963', 'Reparto', '3 premios y 3 nominaciones')]
# Datos de los actores:
# [('Coriolanus', 'Gerard Butler', ['300', 'Un ciudadano ejemplar'], '1969', 'Reparto, Producción, Cámara y electricidad', '6 premios y 17 nominaciones'), ('Coriolanus', 'Ralph Fiennes', ['El jardinero fiel', 'El gran hotel Budapest'], '1962', 'Reparto, Dirección, Producción', 'N/A'), ('Coriolanus', 'Lubna Azabal', ['Incendios', 'Coriolanus'], '1973', 'Reparto', '15 premios y 6 nominaciones'), ('Coriolanus', 'Ashraf Barhom', ['La sombra del reino', 'Coriolanus'], '1979', 'Reparto, Equipos adicionales', '1 premio'), ('Coriolanus', 'Zoran Cica', ['Coriolanus', 'Kosarkasi'], '1981', 'Reparto', '1,90 m'), ('Coriolanus', 'Milos Dabic', ['Coriolanus'], 'N/A', 'Reparto', 'N/A'), ('Coriolanus', 'Nicolas Isia', ['Coriolanus', 'Juzni vetar'], 'N/A', 'Reparto', 'N/A'), ('Coriolanus', 'Zoran Miljkovic', ['Coriolanus', 'Underground'], '1947', 'Reparto, Equipos adicionales', 'Z. Miljkovic')]
# No se encontró el actor número 4
# No se encontró el actor número 5
# Datos de los actores:
# [('The Prodigies', 'Jeffrey Evan Thomas', ['August', 'The Prodigies'], 'N/A', 'Reparto', 'N/A'), ('The Prodigies', 'Dominic Gould', ['Double Team', 'Juegos de espía'], '1964', 'Reparto, Dirección, Guion', 'Domenique Gould'), ('The Prodigies', 'Moon Dailly', ['Crossing Lines', 'No soy un hombre fácil'], 'N/A', 'Reparto, Banda sonora', 'N/A'), ('The Prodigies', 'Milos Dabic', ['Coriolanus'], 'N/A', 'Reparto', 'N/A'), ('The Prodigies', 'Nicolas Isia', ['Coriolanus', 'Juzni vetar'], 'N/A', 'Reparto', 'N/A'), ('The Prodigies', 'Zoran Miljkovic', ['Coriolanus', 'Underground'], '1947', 'Reparto, Equipos adicionales', 'Z. Miljkovic')]
# Datos de los actores:
# [('Lipstikka', 'Clara Khoury', ['Baghdad Central', 'Marjoun and the Flying Headscarf'], '1976', 'Reparto, Banda sonora', '4 premios y 2 nominaciones'), ('Lipstikka', 'Nataly Attiya', ['Lipstikka', 'Manayek'], '1975', 'Reparto', '1 premio'), ('Lipstikka', 'Daniel Caltagirone', ['Lara Croft Tomb Raider: La cuna de la vida', 'El pianista'], '1972', 'Reparto', '1 nominación'), ('Lipstikka', 'Moran Rosenblatt', ['Hit & Run', 'Fauda'], '1985', 'Reparto, Dirección, Guion', '3 premios y 4 nominaciones'), ('Lipstikka', 'Ziv Weiner', ['Lipstikka'], 'N/A', 'Reparto', 'N/A'), ('Lipstikka', 'Gal Lev', ['Karaoke', 'La tercera persona'], 'N/A', 'Composición, Reparto, Música', '1 premio'), ('Lipstikka', 'Ofer Hayoun', ['Six zeros', 'The Baker and the Beauty'], '1983', 'Reparto, Cámara y electricidad', '1 nominación'), ('Lipstikka', 'Taliesin Knight', ['Lipstikka', 'The Fairy Queen'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Alois Nebel', 'Miroslav Krobot', ['Díra u Hanusovic', 'Kvarteto'], '1951', 'Reparto, Dirección, Guion', '4 premios y 11 nominaciones'), ('Alois Nebel', 'Marie Ludvíková', ['A la sombra', 'Venkovský ucitel'], '1957', 'Reparto', 'N/A'), ('Alois Nebel', 'Karel Roden', ['RocknRolla', 'Hellboy'], '1962', 'Reparto, Producción, Banda sonora', '5 premios y 16 nominaciones'), ('Alois Nebel', 'Leos Noha', ['Wasteland', 'Franta Mimozemstan'], '1968', 'Reparto', 'N/A'), ('Alois Nebel', 'Alois Svehlík', ['Na strese', 'Cerní baroni'], '1939', 'Reparto', '1 nominación'), ('Alois Nebel', 'Tereza Ramba', ['Vlastníci', 'Missing'], '1989', 'Reparto', '2 premios y 3 nominaciones'), ('Alois Nebel', 'Ján Sedal', ['Maharal - tajemstvi talismanu', 'Cesta z mesta'], '1948', 'Reparto', 'Jano Sedal'), ('Alois Nebel', 'Miloslav Marsálek', ['Dum pro dva', 'Kvarteto'], '1945', 'Reparto', 'Milan Marsálek')]
# Datos de los actores:
# [('Simon och ekarna', 'Bill Skarsgård', ['It', 'It: Capítulo 2'], '1990', 'Reparto, Producción, Dirección', '7 premios y 12 nominaciones'), ('Simon och ekarna', 'Helen Sjöholm', ['Tierra de ángeles', 'Mamma Mia! Una y otra vez'], '1970', 'Reparto, Música, Banda sonora', '1 nominación'), ('Simon och ekarna', 'Jan Josef Liefers', ['En el lugar del crimen', 'RAF Facción del ejército rojo'], '1964', 'Reparto, Dirección, Producción', '15 premios y 10 nominaciones'), ('Simon och ekarna', 'Stefan Gödicke', ['Un hombre llamado Ove', 'El triángulo de la tristeza'], '1970', 'Reparto', 'N/A'), ('Simon och ekarna', 'Karl Linnertorp', ['Simon och ekarna', 'Morden i Sandhamn'], '1986', 'Reparto, Banda sonora', 'N/A'), ('Simon och ekarna', 'Jonatan S. Wächter', ['Simon och ekarna'], 'N/A', 'Reparto', 'N/A'), ('Simon och ekarna', 'Karl Martin Eriksson', ['Simon och ekarna', 'Dem man elsker'], 'N/A', 'Reparto', 'N/A'), ('Simon och ekarna', 'Erica Löfgren', ['Conventuram', 'Simon och ekarna'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Ma compagne de nuit', 'Emmanuelle Béart', ['8 mujeres', 'Mission: Impossible'], '1963', 'Reparto, Dirección, Guion', '12 premios y 10 nominaciones'), ('Ma compagne de nuit', 'Hafsia Herzi', ['Mereces un amor', 'Bonne mère'], '1987', 'Reparto, Dirección, Guion', '11 premios y 10 nominaciones'), ('Ma compagne de nuit', 'Laurent Grévill', ['La pasión de Camille Claudel', 'El año del despertar'], '1961', 'Reparto', '2 nominaciones'), ('Ma compagne de nuit', 'Bruno Todeschini', ['Su hermano', 'Vete a saber'], '1962', 'Reparto', '1 premio y 3 nominaciones'), ('Ma compagne de nuit', 'Alain Cerrer', ['Suspectes', 'Reporters'], 'N/A', 'Reparto', 'N/A'), ('Ma compagne de nuit', 'Alexandra Stewart', ['Frenético', 'La cara oculta'], '1939', 'Reparto, Equipos adicionales, Banda sonora', '1 premio'), ('Ma compagne de nuit', 'Annabelle Hettmann', ['Elle', 'Enforcer: The Asset'], 'N/A', 'Reparto', '1 nominación'), ('Ma compagne de nuit', 'Lauriane Escaffre', ['Pile poil', 'El despertar de María'], 'N/A', 'Reparto, Guion, Dirección', '1 premio')]
# Datos de los actores:
# [('Play', 'Anas Abdirahman', ['Play'], 'N/A', 'Reparto', 'N/A'), ('Play', 'Sebastian Blyckert', ['Play'], 'N/A', 'Reparto', 'N/A'), ('Play', 'Yannick Diakité', ['Play'], 'N/A', 'Reparto', 'N/A'), ('Play', 'Sebastian Hegmar', ['Play'], 'N/A', 'Reparto', 'N/A'), ('Play', 'Abdiaziz Hilowle', ['Play'], 'N/A', 'Reparto', 'N/A'), ('Play', 'Nana Manu', ['El triángulo de la tristeza', 'Alex'], 'N/A', 'Reparto', 'N/A'), ('Play', 'John Ortiz', ['Play'], 'N/A', 'Reparto, Banda sonora', 'N/A'), ('Play', 'Kevin Vaz', ['Play', 'Under pyramiden'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('My Angel', 'Jassa Ahluwalia', ["Heart's Ease", 'Peaky Blinders'], '1990', 'Reparto, Producción, Dirección', 'N/A'), ('My Angel', 'Elijah Baker', ['The Batman', 'Injusticia (Miniserie de TV)'], '1991', 'Reparto, Guion, Producción', '1 premio'), ('My Angel', 'Brenda Blethyn', ['Pride & Prejudice (Orgullo y prejuicio)', 'Secretos y mentiras'], '1946', 'Reparto, Guion, Banda sonora', '21 premios y 42 nominaciones en total'), ('My Angel', 'Janet Dibley', ['Gold', 'Gente de barrio'], '1958', 'Reparto, Guion, Banda sonora', 'N/A'), ('My Angel', 'Ellie Greenwood', ['My Angel'], 'N/A', 'Reparto', 'N/A'), ('My Angel', 'Angus Harrison', ['Skins', 'Casualty'], 'N/A', 'Reparto', 'N/A'), ('My Angel', 'Celia Imrie', ['El exótico Hotel Marigold', 'Rosas Rojas'], '1952', 'Reparto, Banda sonora', '3 premios y 3 nominaciones'), ('My Angel', 'David McEwan', ['Born to Spy', 'Dark Place'], 'N/A', 'Equipos adicionales, Reparto', 'N/A')]
# Datos de los actores:
# [('Cesado', 'Carmen Vicarte', ['La montaña del diablo', 'Cesado'], 'N/A', 'Reparto', 'N/A'), ('Cesado', 'Jorge Bartolucci', ['Cesado'], 'N/A', 'Reparto', 'N/A'), ('Cesado', 'Julian Gonzalez de Leon', ['Cesado'], 'N/A', 'Reparto', 'N/A'), ('Cesado', 'Tania Marquina', ['Cesado'], 'N/A', 'Reparto', 'N/A'), ('Cesado', 'Luis Lince', ['Cesado'], 'N/A', 'Reparto', 'N/A'), ('Cesado', 'Angela Vázquez González', ['Cesado'], 'N/A', 'Reparto', 'N/A'), ('Cesado', 'Inn Klikotskaia', ['Cazador de serpientes', 'Cesado'], 'N/A', 'Reparto', 'N/A'), ('Cesado', 'Consuelo Prieto', ['Cesado'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Hero Nanalla', 'Ravi Chethan', ['Vishnuvardhana', 'Kotigobba 2'], 'N/A', 'Reparto', 'Chethan'), ('Hero Nanalla', 'M.N. Lakshmi Devi', ['Namma Basava', 'Sathyam'], 'N/A', 'Reparto', 'N/A'), ('Hero Nanalla', 'Jai Jagdeesh', ['Madana', 'Kurigalu Saar Kurigalu'], 'N/A', 'Reparto, Producción, Dirección', 'N/A'), ('Hero Nanalla', 'Bank Janardhan', ['Uppi 2', 'Kotigobba 2'], 'N/A', 'Reparto', 'Swamiji'), ('Hero Nanalla', 'Pavan', ['Hero Nanalla'], 'N/A', 'Reparto', 'N/A'), ('Hero Nanalla', 'Sahana', ['Hero Nanalla'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Jedarahalli', 'Shankar Ashwath', ['RangiTaranga', 'Huchudugaru'], 'N/A', 'Reparto', 'N/A'), ('Jedarahalli', 'Dharma', ['Maanikya', 'Indru Netru Naalai'], 'N/A', 'Reparto', 'N/A'), ('Jedarahalli', 'Karibasavaiah', ['Yogi', 'Vande Mataram'], '1959', 'Reparto, Música', 'N/A'), ('Jedarahalli', 'H.M. Krishnamurthy', ['Jedarahalli', 'Devadas'], 'N/A', 'Reparto, Producción, Guion', 'N/A'), ('Jedarahalli', 'Srinivasa Murthy', ['K.G.F: Chapter 1', 'K.G.F: Chapter 2'], '1949', 'Reparto, Dirección de la segunda unidad o asistencia a dirección', 'N/A'), ('Jedarahalli', 'Shweta Pandit', ['Urvi', 'Case No.18/9'], 'N/A', 'Reparto', 'N/A'), ('Jedarahalli', 'Ashok Rao', ['Bombaat', 'Cyanide'], '2022', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Vishnu', 'Abhijit', ['Vishnu', 'Jodi No. 1'], 'N/A', 'Reparto, Guion, Dirección', 'N/A'), ('Vishnu', 'Ravishankar Gowda', ['VR (Vikrant Rona)', 'Mysore Huli'], 'N/A', 'Reparto, Música', 'N/A'), ('Vishnu', 'Sharath Lohitashwa', ['Aa Dinagalu', 'Saarathi'], '1972', 'Reparto', 'N/A'), ('Vishnu', 'Bullet Prakash', ['Bachchan', 'Bhajarangi'], '2020', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Onde Ondu Saari', 'Jadi Akash', ['Krishnan Love Story', 'Beega'], 'N/A', 'Reparto', 'N/A'), ('Onde Ondu Saari', 'Ramesh', ['Onde Ondu Saari'], 'N/A', 'Reparto', 'N/A')]
# No se encontró el actor número 1
# No se encontró el actor número 2
# No se encontró el actor número 5
# No se encontró el actor número 6
# No se encontró el actor número 7
# No se encontró el actor número 8
# Datos de los actores:
# [('We are all sinners', 'Kishore Shetty', ['Onde Ondu Saari'], 'N/A', 'Reparto', 'N/A'), ('We are all sinners', 'Shwetha', ['Onde Ondu Saari'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [("Love Is a Thieves' Game", 'Sam Logan Khaleghi', ['Batman v Superman: El amanecer de la justicia', 'Approaching Midnight'], '1983', 'Producción, Reparto, Dirección', '3 nominaciones'), ("Love Is a Thieves' Game", 'Kristen Pickthall', ["Love Is a Thieves' Game"], 'N/A', 'Reparto', 'N/A'), ("Love Is a Thieves' Game", 'Jason Waugh', ['Blood Games', 'Stone'], '1968', 'Reparto, Dirección de fotografía y cámara, Diseño de producción', 'N/A'), ("Love Is a Thieves' Game", 'Jeffery Stetson', ["Love Is a Thieves' Game", "Devil's Night: Dawn of the Nain Rouge"], 'N/A', 'Reparto', 'Jeffry W. Stetson'), ("Love Is a Thieves' Game", 'Marius Iliescu', ['Adios Vaya Con Dios', 'Arise from Darkness'], '1967', 'Reparto, Producción, Dirección de arte', '1 premio y 6 nominaciones'), ("Love Is a Thieves' Game", 'Darryl Perry', ["Love Is a Thieves' Game", 'Butterfly Kisses'], 'N/A', 'Reparto, Sonido, Dirección de la segunda unidad o asistencia a dirección', 'N/A'), ("Love Is a Thieves' Game", 'Rockey Black', ['8 millas', 'Gotcha!'], 'N/A', 'Producción, Reparto, Dirección', '1,75 m'), ("Love Is a Thieves' Game", 'Erin Cunningham', ['Diverge', "Love Is a Thieves' Game"], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Tatal fantoma', 'Marcel Iures', ['Piratas del Caribe: En el fin del mundo', 'El pacificador'], '1951', 'Reparto', '14 premios y 1 nominación'), ('Tatal fantoma', 'Barry Gifford', ['Carretera perdida', 'Corazón salvaje'], '1946', 'Guion, Reparto, Producción', 'N/A'), ('Tatal fantoma', 'Mihaela Sirbu', ['Toata lumea din familia noastra', 'Aferim!'], '1971', 'Reparto, Producción', '2 premios y 1 nominación'), ('Tatal fantoma', 'Valer Dellakeza', ['Clouds of Chernobyl', 'Tatal fantoma'], '1942', 'Reparto', '1 nominación'), ('Tatal fantoma', 'Mihai Constantin', ['Si quiero silbar, silbo', "Liceenii Rock 'n' Roll"], '1964', 'Reparto', 'N/A'), ('Tatal fantoma', 'Mimi Branescu', ['Martes, después de Navidad', 'Acasã la tata'], '1974', 'Guion, Reparto, Producción', '2 premios y 5 nominaciones'), ('Tatal fantoma', 'Victor Rebengiuc', ['Medalia de onoare', 'Octav'], '1933', 'Reparto', '13 premios y 1 nominación'), ('Tatal fantoma', 'Mariana Mihut', ['Ultima frontiera a mortii', 'Padurea spânzuratilor'], '1942', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Hella W', 'Tiina Weckström', ['Tulennielijä', 'Hella W'], '1956', 'Reparto, Banda sonora', 'N/A'), ('Hella W', 'Hannu-Pekka Björkman', ['Ihmisen osa', 'Eläville ja kuolleille'], '1969', 'Reparto, Dirección, Edición', '7 premios y 2 nominaciones'), ('Hella W', 'Matleena Kuusniemi', ['Koukussa', 'Tumman veden päällä'], '1973', 'Reparto, Guion y continuidad, Banda sonora', 'N/A'), ('Hella W', 'Maria Heiskanen', ['Los momentos eternos de Maria Larssons', 'Il capitano'], '1970', 'Reparto, Equipos adicionales', '4 premios y 3 nominaciones'), ('Hella W', 'Antti Litja', ['El gruñón', 'Mies, joka ei osannut sanoa EI'], '1938', 'Reparto, Banda sonora', '3 premios'), ('Hella W', 'Pirkka-Pekka Petelius', ['Team Ahma', 'Hamlet va de negocios'], '1953', 'Reparto, Guion, Producción', '6 premios y 2 nominaciones'), ('Hella W', 'Svante Martin', ['Arn: El caballero templario', 'Arn'], '1948', 'Reparto', 'N/A'), ('Hella W', 'Petri Manninen', ['Korso', 'Vares - yksityisetsivä'], '1965', 'Reparto', 'Petteri Manninen')]
# Datos de los actores:
# []
# Datos de los actores:
# [('American Disciples', 'Jeffrey Weissman', ['Regreso al futuro: Parte II', 'El jinete pálido'], '1958', 'Reparto, Producción, Equipos adicionales', 'N/A'), ('American Disciples', 'Michelle Page', ['Miss Agente Especial 2: Armada y fabulosa', 'American Horror Story'], '1987', 'Reparto, Producción', '1 premio'), ('American Disciples', 'Elijah Nelson', ['Crazy Ex-Girlfriend', "Ira Finkelstein's Christmas"], '1999', 'Reparto, Guion, Producción', '3 premios'), ('American Disciples', 'Robert Blanche', ['Hombres de honor', 'Rose Red'], '1962', 'Reparto, Guion, Producción', '1 premio'), ('American Disciples', 'Jana Lee Hamblin', ['Ya no me siento a gusto en este mundo', 'El ala oeste de la Casa Blanca'], 'N/A', 'Reparto, Dirección, Equipos adicionales', 'N/A'), ('American Disciples', 'Erin McGarry', ['Death on a Rock', 'Blue Like Jazz'], 'N/A', 'Reparto', '1 premio y 4 nominaciones'), ('American Disciples', 'Daniel Nelson', ['American Disciples', 'Shiloh and Bros'], '1997', 'Guion, Producción, Reparto', '1,78 m'), ('American Disciples', 'Brett Donowho', ['Camino de la venganza', 'Actos de violencia'], 'febrero', 'Dirección, Producción, Reparto', '4 premios')]
# Datos de los actores:
# [('Bella Biondina', 'Miljenka Androic', ['El Dios Rata', 'Bella Biondina'], '1954', 'Reparto', 'N/A'), ('Bella Biondina', 'Inge Appelt', ['Ljubav i poneka psovka', 'Fine mrtve djevojke'], '1943', 'Reparto', 'N/A'), ('Bella Biondina', 'Ana Begic Tahiri', ['Vatre Ivanjske', 'Bella Biondina'], '1979', 'Reparto', 'N/A'), ('Bella Biondina', 'Vicko Bilandzic', ['Bella Biondina', 'Loza'], '1977', 'Reparto', 'N/A'), ('Bella Biondina', 'Karla Brbic', ['Ja sam svoj zivot poslozila', 'Bella Biondina'], '1987', 'Reparto', 'N/A'), ('Bella Biondina', 'Boris Buzancic', ['67 días', 'Kotlovina'], '1929', 'Reparto', 'B. Buzancic'), ('Bella Biondina', 'Zrinka Cvitesic', ['En el camino', 'Sto je muskarac bez brkova?'], '1979', 'Reparto, Guion, Producción', '4 premios y 1 nominación'), ('Bella Biondina', 'Branka Cvitkovic', ['Ljubavi Georgea Washingtona', 'Bella Biondina'], '1948', 'Reparto, Equipos adicionales', 'N/A')]
# Datos de los actores:
# [('Deuce of Spades', 'Timothy Luke', ['El libro de la selva', 'Deuce of Spades'], 'N/A', 'Cámara y electricidad, Reparto, Dirección de fotografía y cámara', 'N/A'), ('Deuce of Spades', 'Faith Granger', ['Deuce of Spades', 'Against All Odds, the Making of DEUCE of SPADES'], 'N/A', 'Producción, Dirección, Guion', 'N/A'), ('Deuce of Spades', 'Alexandra Holder', ['Honeymoon', 'Deuce of Spades'], 'N/A', 'Reparto, Vestuario, Equipos adicionales', 'N/A'), ('Deuce of Spades', 'Jordan Warren', ['The Black Dawn', 'The Black Dawn'], 'N/A', 'Producción, Reparto, Guion', 'N/A'), ('Deuce of Spades', 'Kyle Clifford', ['Deuce of Spades', 'Against All Odds, the Making of DEUCE of SPADES'], 'N/A', 'Reparto', 'N/A'), ('Deuce of Spades', 'Kristin Findley', ['Friends 4ever', 'Deuce of Spades'], 'N/A', 'Reparto', 'N/A'), ('Deuce of Spades', 'Carol-Lynn Campbell', ['Deuce of Spades', 'Short on Time'], 'N/A', 'Reparto', 'N/A'), ('Deuce of Spades', 'Gary Miller-Youst', ['Deuce of Spades', 'Los exterminadores'], '1943', 'Reparto', 'Gary Youst')]
# Datos de los actores:
# [('Elle ne pleure pas, elle chante', 'Erika Sainte', ['Je suis resté dans les bois', 'Elle ne pleure pas, elle chante'], '1981', 'Reparto, Dirección, Guion', '1 premio y 2 nominaciones'), ('Elle ne pleure pas, elle chante', 'Laurent Capelluto', ['Las vidas posibles de Mr. Nobody', 'Fils unique'], '1971', 'Reparto', '3 premios y 6 nominaciones'), ('Elle ne pleure pas, elle chante', 'Marijke Pinoy', ['Ben X', 'De Dag'], '1958', 'Reparto, Equipos adicionales', 'N/A'), ('Elle ne pleure pas, elle chante', 'Jean-François Wolff', ['JCVD', 'El mercader de Venecia'], '1963', 'Reparto', 'Jean François Wolff'), ('Elle ne pleure pas, elle chante', 'Jules Werner', ['El mercader de Venecia', 'Doudege Wénkel'], 'N/A', 'Reparto', 'N/A'), ('Elle ne pleure pas, elle chante', 'Vicky Krieps', ['El hilo invisible', 'Tiempo'], '1983', 'Reparto, Producción, Banda sonora', '19 premios y 18 nominaciones'), ('Elle ne pleure pas, elle chante', 'Martin De Myttenaere', ['Les Revenants', 'La forêt'], 'N/A', 'Reparto', 'N/A'), ('Elle ne pleure pas, elle chante', 'Galatéa Bellugi', ['9 meses', 'La aparición'], 'N/A', 'Reparto', '1 premio y 3 nominaciones')]
# Datos de los actores:
# [('Muerte de un superhéroe', 'Thomas Brodie-Sangster', ['El corredor del laberinto: Las pruebas', 'El corredor del laberinto'], '1990', 'Reparto, Producción, Banda sonora', '4 premios y 12 nominaciones en total'), ('Muerte de un superhéroe', 'Lilly Forgách', ['Muerte de un superhéroe', 'Ludwig II'], '1966', 'Reparto', 'N/A'), ('Muerte de un superhéroe', 'Ian Fitzgibbon', ['Muerte de un superhéroe', 'A Film with Me in It'], '1962', 'Dirección, Reparto, Guion', 'N/A'), ('Muerte de un superhéroe', 'Michael McElhatton', ['Juego de tronos', 'Jack Ryan'], '1963', 'Reparto, Guion', '3 premios y 9 nominaciones'), ('Muerte de un superhéroe', 'Sharon Horgan', ['Catastrophe', 'This Way Up'], '1970', 'Reparto, Producción, Guion', '16 premios y 40 nominaciones en total'), ('Muerte de un superhéroe', 'Ronan Raftery', ['Animales fantásticos y dónde encontrarlos', 'El asedio de Jadotville'], 'N/A', 'Reparto, Producción', 'N/A'), ('Muerte de un superhéroe', 'Andy Serkis', ['La guerra del planeta de los simios', 'El origen del planeta de los simios'], '1964', 'Reparto, Producción, Dirección', '43 premios y 63 nominaciones en total'), ('Muerte de un superhéroe', 'Aisling Loftus', ['El descubrimiento de las brujas', 'Mr. Selfridge'], '1990', 'Reparto', '1 premio y 1 nominación')]
# Datos de los actores:
# [('The Other End', 'Bridgett Hawke', ['The Black Caesar', 'Deal'], 'N/A', 'Reparto', 'N/A'), ('The Other End', 'Tony Devon', ['Pizza with Bullets', 'Impacto'], '1951', 'Reparto, Producción, Guion', '1 premio'), ('The Other End', 'Piper Varagot', ['The Woods', 'Avenge Me'], 'N/A', 'Reparto', 'N/A'), ('The Other End', 'Brian Keating', ['Eager to Die', 'The Other End'], 'N/A', 'Reparto', 'N/A'), ('The Other End', 'Woody Hall', ['The Other End'], 'N/A', 'Reparto', 'N/A'), ('The Other End', 'Cherice Hayes', ['The Other End'], 'N/A', 'Reparto', 'N/A'), ('The Other End', 'Denise Stefan', ['The Other End'], 'N/A', 'Reparto', 'N/A'), ('The Other End', 'Matilda Pierre', ['The Other End'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Rokland', 'Ólafur Darri Ólafsson', ['Festival de la Canción de Eurovisión: La historia de Fire Saga', 'La vida secreta de Walter Mitty'], '1973', 'Reparto, Producción, Guion', '6 premios y 8 nominaciones'), ('Rokland', 'Þorsteinn Bachmann', ['Katla', 'True Detective'], '1965', 'Reparto, Equipos adicionales, Producción', '4 premios y 7 nominaciones'), ('Rokland', 'Hilmir Snær Guðnason', ['Brúðguminn', 'Lamb'], '1969', 'Reparto, Guion, Dirección', '4 premios y 4 nominaciones'), ('Rokland', 'Lára Jóhanna Jónsdóttir', ['Déjame caer', 'Sense8'], 'N/A', 'Reparto', 'N/A'), ('Rokland', 'Þórhallur Sigurðsson', ['La vida secreta de Walter Mitty', 'Stella í framboði'], '1947', 'Reparto, Dirección, Guion', "Þórhallur Sigurðsson 'Laddi'"), ('Rokland', 'Jóhann Sigurðarson', ['Fornbókabúðin', 'La mujer de la montaña'], '1956', 'Reparto, Dirección, Guion', 'N/A'), ('Rokland', 'Jafet Máni Magnúsarson', ['Stella Blómkvist', 'Trust'], 'N/A', 'Reparto, Dirección', 'N/A'), ('Rokland', 'Víkingur Kristjánsson', ['Foreldrar', 'Vegferð'], '1972', 'Reparto, Producción, Guion', 'N/A')]
# No se encontró el actor número 2
# No se encontró el actor número 3
# Datos de los actores:
# [('This Is Not a Movie', 'Edward Furlong', ['Terminator 2: El juicio final', 'Cero en conducta'], '1977', 'Reparto, Producción, Banda sonora', '4 premios y 6 nominaciones'), ('This Is Not a Movie', 'Lára Jóhanna Jónsdóttir', ['Déjame caer', 'Sense8'], 'N/A', 'Reparto', 'N/A'), ('This Is Not a Movie', 'Þórhallur Sigurðsson', ['La vida secreta de Walter Mitty', 'Stella í framboði'], '1947', 'Reparto, Dirección, Guion', "Þórhallur Sigurðsson 'Laddi'"), ('This Is Not a Movie', 'Jóhann Sigurðarson', ['Fornbókabúðin', 'La mujer de la montaña'], '1956', 'Reparto, Dirección, Guion', 'N/A')]
# Datos de los actores:
# [('Un lugar para soñar', 'Matt Damon', ['El indomable Will Hunting', 'Marte (The Martian)'], '1970', 'Producción, Reparto, Guion', 'N/A'), ('Un lugar para soñar', 'Scarlett Johansson', ['Her', 'Lost in Translation'], '1984', 'Reparto, Producción, Dirección', 'N/A'), ('Un lugar para soñar', 'Thomas Haden Church', ['Entre copas', 'Spider-Man 3'], '1960', 'Reparto, Equipos adicionales, Producción', '30 premios y 25 nominaciones en total'), ('Un lugar para soñar', 'Colin Ford', ['Un lugar para soñar', 'Push'], 'septiembre', 'Reparto, Equipos adicionales, Banda sonora', '4 premios y 6 nominaciones'), ('Un lugar para soñar', 'Maggie Elizabeth Jones', ['Un lugar para soñar', 'La primera vez'], '2003', 'Reparto', '1 premio y 2 nominaciones'), ('Un lugar para soñar', 'Angus Macfadyen', ['Equilibrium', 'Saw III'], '1963', 'Reparto, Guion, Dirección', '1 premio y 9 nominaciones'), ('Un lugar para soñar', 'Elle Fanning', ['Super 8', 'The Neon Demon'], '1998', 'Reparto, Producción, Dirección', '14 premios y 61 nominaciones en total'), ('Un lugar para soñar', 'Patrick Fugit', ['Casi famosos', 'Perdida'], '1982', 'Reparto, Producción, Cámara y electricidad', '4 premios y 16 nominaciones')]
# Datos de los actores:
# [('Solos en la ciudad', 'Felipe Colombo', ['Erreway: 4 caminos', 'Chiquititas: Rincón de luz'], '1983', 'Reparto, Composición, Banda sonora', 'N/A'), ('Solos en la ciudad', 'Sabrina Garciarena', ['Felicitas', 'Se dice amor'], '1983', 'Reparto, Banda sonora', '1 premio'), ('Solos en la ciudad', 'Mario Pasik', ['Son de Fierro', "Verano del '98"], '1951', 'Reparto', '3 nominaciones'), ('Solos en la ciudad', 'Catherine Fulop', ['Rebelde Way', 'Abigail'], '1965', 'Reparto', '1,75 m'), ('Solos en la ciudad', 'María Abadi', ['Montecristo', 'Ciega a citas'], '1985', 'Reparto', '1 premio y 3 nominaciones'), ('Solos en la ciudad', 'Federico Amador', ['El tiempo no para', 'Herederos de una venganza'], '1975', 'Reparto, Banda sonora', 'María José Becherucci'), ('Solos en la ciudad', 'Laura Azcurra', ['Verdad consecuencia', 'R.R.D.T'], '1981', 'Reparto, Banda sonora', 'N/A'), ('Solos en la ciudad', 'Luciano Leyrado', ['Oliva', 'El duelo'], '1978', 'Reparto, Producción, Dirección', 'N/A')]
# Datos de los actores:
# [('Tierra de asesinatos', 'Sam Worthington', ['Avatar', 'Terminator: Salvation'], '1976', 'Reparto, Producción, Dirección', '6 premios y 20 nominaciones'), ('Tierra de asesinatos', 'Jeffrey Dean Morgan', ['Watchmen', 'Proyecto Rampage'], '1966', 'Reparto, Producción, Banda sonora', '6 premios y 8 nominaciones'), ('Tierra de asesinatos', 'Jessica Chastain', ['La noche más oscura', "Molly's Game"], '1977', 'Reparto, Producción, Banda sonora', 'N/A'), ('Tierra de asesinatos', 'Chloë Grace Moretz', ['Kick-Ass: Listo para machacar', 'Déjame entrar'], '1997', 'Reparto, Producción, Banda sonora', '29 premios y 49 nominaciones'), ('Tierra de asesinatos', 'Jason Clarke', ['La noche más oscura', 'Mudbound'], '1969', 'Reparto, Producción', '6 premios y 11 nominaciones'), ('Tierra de asesinatos', 'Annabeth Gish', ['Mystic Pizza', 'Beautiful Girls'], '1971', 'Reparto', '2 premios y 5 nominaciones'), ('Tierra de asesinatos', 'Sheryl Lee', ['Twin Peaks: Fuego camina conmigo', 'Vampiros de John Carpenter'], '1967', 'Reparto, Equipos adicionales, Casting', '1 premio y 6 nominaciones'), ('Tierra de asesinatos', 'Stephen Graham', ['This Is England', 'Hierve'], '1973', 'Reparto, Producción, Guion', '14 premios y 21 nominaciones en total')]
# Datos de los actores:
# [('Oscar', 'Priyanka Bulgannawar', ['Marujanma', 'Oscar'], 'N/A', 'Reparto', 'N/A'), ('Oscar', 'Rajendra Karanth', ['Mangana Kaili Manikya', 'Accident'], 'N/A', 'Reparto, Guion, Dirección', 'N/A'), ('Oscar', 'Ashok Kumar', ['Oscar'], 'N/A', 'Reparto', 'N/A'), ('Oscar', 'Sangeetha Shetty', ['Porki', 'Varshadhaare'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('5 Idiots', 'Master Anand', ['5 Idiots', 'Nigooda Raatri'], 'N/A', 'Dirección, Reparto, Guion', 'N/A'), ('5 Idiots', 'Vaijanath Biradar', ['Kanasembo kudureyaneri', 'Uppi 2'], 'N/A', 'Reparto', 'N/A'), ('5 Idiots', 'Chidanand', ['Mr. Garagasa', 'Citizen'], 'N/A', 'Reparto', 'N/A'), ('5 Idiots', 'Mimicry Dayanand', ['Night Duty', 'Anireekshitha'], 'N/A', 'Reparto, Dirección, Producción', 'Dom'), ('5 Idiots', 'Namratha Hegde', ['Sompa', '5 Idiots'], 'N/A', 'Reparto, Producción', 'N/A'), ('5 Idiots', 'Bank Janardhan', ['Uppi 2', 'Kotigobba 2'], 'N/A', 'Reparto', 'Swamiji'), ('5 Idiots', 'Karibasavaiah', ['Yogi', 'Vande Mataram'], '1959', 'Reparto, Música', 'N/A'), ('5 Idiots', 'Naveen Krishna', ['Ouija: Game Never Ends', 'Haggada Kone: End of the Rope'], 'N/A', 'Reparto, Música, Guion', 'N/A')]
# Datos de los actores:
# [('106 Kanasu', 'Vasu Biradar', ['106 Kanasu'], 'N/A', 'Reparto', 'N/A')]
# No se encontró el actor número 1
# No se encontró el actor número 2
# No se encontró el actor número 4
# No se encontró el actor número 5
# Datos de los actores:
# [('Kadhimaru', 'Shreyas', ['106 Kanasu'], 'N/A', 'Reparto', 'N/A'), ('Kadhimaru', 'Bank Janardhan', ['Uppi 2', 'Kotigobba 2'], 'N/A', 'Reparto', 'Swamiji'), ('Kadhimaru', 'Karibasavaiah', ['Yogi', 'Vande Mataram'], '1959', 'Reparto, Música', 'N/A')]
# Datos de los actores:
# [('90', 'Vaijanath Biradar', ['Kanasembo kudureyaneri', 'Uppi 2'], 'N/A', 'Reparto', 'N/A'), ('90', 'Chikkanna', ['Master Piece', 'Kotigobba 2'], 'N/A', 'Reparto, Dirección, Música', '3 premios y 3 nominaciones'), ('90', 'Doddanna', ['Aatagadharaa Siva', 'Ajay'], 'N/A', 'Reparto, Música', '1 nominación'), ('90', 'Laya Kokila', ['Male Nilluvavarege', 'Onti Mane'], 'N/A', 'Reparto, Composición, Música', 'Layendra'), ('90', 'Sadhu Kokila', ['Mr. Theertha', 'Mr. And Mrs. Ramchari'], '1966', 'Reparto, Composición, Música', '2 premios y 5 nominaciones'), ('90', 'Nagaraj Kote', ['Jagath Kiladi', 'Haalu Thuppa'], 'N/A', 'Reparto', 'N/A'), ('90', 'Michael Madhu', ['Om', 'AK 47'], '2020', 'Reparto', '(un ataque al corazón)'), ('90', 'Bullet Prakash', ['Bachchan', 'Bhajarangi'], '2020', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Aptha', 'Pooja Gandhi', ['Krishna', 'Accident'], '1983', 'Reparto, Música, Producción', 'N/A'), ('Aptha', 'Sadhu Kokila', ['Mr. Theertha', 'Mr. And Mrs. Ramchari'], '1966', 'Reparto, Composición, Música', '2 premios y 5 nominaciones')]
# Datos de los actores:
# [('Boss', 'Navya Nair', ['Oruthee', 'Gramaphone'], '1985', 'Reparto', '1 nominación'), ('Boss', 'Prabhu', ['Ponniyin Selvan: Part One', 'Ayan'], '1956', 'Reparto, Producción, Música', '2 premios y 1 nominación'), ('Boss', 'Shivaji Prabhu', ['Boss'], 'N/A', 'Reparto', 'N/A'), ('Boss', 'Bullet Prakash', ['Bachchan', 'Bhajarangi'], '2020', 'Reparto', 'N/A'), ('Boss', 'Rangayana Raghu', ['Johny Mera Naam Preethi Mera Kaam', 'Hudugaru'], 'N/A', 'Reparto, Música, Banda sonora', '1 premio y 8 nominaciones'), ('Boss', 'Sumithra', ['Nizhal Nijamakirathu', 'Valimai'], 'N/A', 'Reparto', 'N/A'), ('Boss', 'Supreet', ['Saaho', 'Brindaavanam'], 'N/A', 'Reparto', 'N/A'), ('Boss', 'Darshan Thoogudeep', ['Saarathi', 'Kranthiveera Sangolli Rayanna'], '1977', 'Reparto, Música', '4 premios y 5 nominaciones')]
# Datos de los actores:
# [('Mathond Madhuvena', 'Priyanka Chandra', ['Krishnan Marriage Story', '10th Class A Sec'], 'N/A', 'Reparto', 'N/A'), ('Mathond Madhuvena', 'Jeniffer', ['Yaadein...', 'Jogi the King'], '1983', 'Reparto', 'N/A'), ('Mathond Madhuvena', 'Naveen Krishna', ['Ouija: Game Never Ends', 'Haggada Kone: End of the Rope'], 'N/A', 'Reparto, Música, Guion', 'N/A'), ('Mathond Madhuvena', 'Anant Nag', ['K.G.F: Chapter 1', 'Godhi Banna Sadharana Mykattu'], '1948', 'Reparto, Música, Guion', '2 premios'), ('Mathond Madhuvena', 'Swasthik Shankar', ['Hubballi', 'Mandya'], 'N/A', 'Reparto', 'N/A'), ('Mathond Madhuvena', 'Sharan', ['Kempe Gowda', 'Adhyaksha'], 'N/A', 'Reparto, Dirección, Guion', '4 nominaciones'), ('Mathond Madhuvena', 'Suhasini', ['Mutthina Haara', 'Indira'], '1961', 'Reparto, Guion, Producción', '11 premios y 4 nominaciones'), ('Mathond Madhuvena', 'Veena Sundar', ['Dheeran', 'Kotigobba 2'], 'N/A', 'Reparto', 'Veena Sunder')]
# Datos de los actores:
# [('Hori', 'Sadashiva Brahmavar', ['Guri', 'Golibar'], '2018', 'Reparto', 'N/A'), ('Hori', 'Suresh Chandra', ['Kiccha Huccha', 'Appayya'], '2021', 'Reparto', 'N/A'), ('Hori', 'Ramneetu Chaudhary', ['Raaj', 'Kataariveera Surasundaraangi'], 'N/A', 'Reparto', 'N/A'), ('Hori', 'Ravi Chethan', ['Vishnuvardhana', 'Kotigobba 2'], 'N/A', 'Reparto', 'Chethan'), ('Hori', 'Doddanna', ['Aatagadharaa Siva', 'Ajay'], 'N/A', 'Reparto, Música', '1 nominación'), ('Hori', 'Karibasavaiah', ['Yogi', 'Vande Mataram'], '1959', 'Reparto, Música', 'N/A'), ('Hori', 'Tennis Krishna', ['Uppi 2', 'Veera Madakari'], 'N/A', 'Reparto, Música, Banda sonora', 'N/A'), ('Hori', 'Adi Lokesh', ['Raaj', 'Circus'], 'N/A', 'Reparto', 'Adhi Lokesh')]
# Datos de los actores:
# [('Ellellu Neene Nannallu Neene', 'Neenasam Ashwath', ['K.G.F: Chapter 1', 'Vishnuvardhana'], 'N/A', 'Reparto', 'Nenasam Ashwath'), ('Ellellu Neene Nannallu Neene', 'Namratha Hegde', ['Sompa', '5 Idiots'], 'N/A', 'Reparto, Producción', 'N/A'), ('Ellellu Neene Nannallu Neene', 'Suresh Mangaluru', ['Brahma', 'Rickshaw Driver'], 'N/A', 'Reparto', 'N/A'), ('Ellellu Neene Nannallu Neene', 'Akshay Ramamurthy', ['Ellellu Neene Nannallu Neene'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Obavva', 'Ayesha', ['Jayahe', 'Lady Boss'], 'N/A', 'Reparto', 'N/A'), ('Obavva', 'Raju Bayya', ['Obavva'], 'N/A', 'Reparto', 'N/A'), ('Obavva', 'Deepak', ['Shishya', 'Arundhati'], 'N/A', 'Reparto, Música', 'N/A'), ('Obavva', 'Bullet Prakash', ['Bachchan', 'Bhajarangi'], '2020', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Kalgejje', 'Neenasam Ashwath', ['K.G.F: Chapter 1', 'Vishnuvardhana'], 'N/A', 'Reparto', 'Nenasam Ashwath'), ('Kalgejje', 'Pavitra Lokesh', ['Malli Malli Idhi Rani Roju', 'Race Gurram'], 'N/A', 'Reparto', '2 nominaciones'), ('Kalgejje', 'S. Mahendar', ['Vaalee', 'Megha Bantu Megha'], 'N/A', 'Dirección de arte, Dirección, Guion', 'S. Mahender'), ('Kalgejje', 'V. Manohar', ['Indradhanush', 'Sye'], 'N/A', 'Música, Composición, Reparto', 'N/A'), ('Kalgejje', 'Anant Nag', ['K.G.F: Chapter 1', 'Godhi Banna Sadharana Mykattu'], '1948', 'Reparto, Música, Guion', '2 premios'), ('Kalgejje', 'T.S. Nagabharana', ['Janumada Jodi', 'K.G.F: Chapter 1'], '1953', 'Dirección, Reparto, Guion', '1 premio y 1 nominación'), ('Kalgejje', 'Tabla Nani', ['Kaanchaana', 'RC Brothers'], 'N/A', 'Reparto, Guion', 'Nani'), ('Kalgejje', 'Rangayana Raghu', ['Johny Mera Naam Preethi Mera Kaam', 'Hudugaru'], 'N/A', 'Reparto, Música, Banda sonora', '1 premio y 8 nominaciones')]
# Datos de los actores:
# [('Dudde Doddappa', 'M.N. Lakshmi Devi', ['Namma Basava', 'Sathyam'], 'N/A', 'Reparto', 'N/A'), ('Dudde Doddappa', 'Jaggesh', ['Guru', 'Neer Dose'], 'N/A', 'Reparto, Música, Producción', 'N/A'), ('Dudde Doddappa', 'Bank Janardhan', ['Uppi 2', 'Kotigobba 2'], 'N/A', 'Reparto', 'Swamiji'), ('Dudde Doddappa', 'Girija Lokesh', ['Martin', 'Gajakesari'], 'N/A', 'Reparto', 'N/A'), ('Dudde Doddappa', 'Pavitra Lokesh', ['Malli Malli Idhi Rani Roju', 'Race Gurram'], 'N/A', 'Reparto', '2 nominaciones'), ('Dudde Doddappa', 'Mohan Shankar', ['Manjunatha BA LLB', 'Guru'], 'N/A', 'Reparto, Guion, Música', 'Mohan'), ('Dudde Doddappa', 'Lakshmi Sharma', ['Dhrona 2010', 'Priyappetta Nattukare'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# []
# Datos de los actores:
# [('Manasology', 'Rakesh Adiga', ['Night Out', 'David'], 'N/A', 'Reparto, Dirección, Guion', 'N/A'), ('Manasology', 'Amoolya', ['Bigil', 'Manasology'], 'N/A', 'Reparto', 'N/A'), ('Manasology', 'Amulya', ['Shravani Subramanya', 'Gajakesari'], 'N/A', 'Reparto', '2 premios y 2 nominaciones'), ('Manasology', 'Sadhu Kokila', ['Mr. Theertha', 'Mr. And Mrs. Ramchari'], '1966', 'Reparto, Composición, Música', '2 premios y 5 nominaciones')]
# Datos de los actores:
# [('Namitha I Love You', 'Bank Janardhan', ['Uppi 2', 'Kotigobba 2'], 'N/A', 'Reparto', 'Swamiji'), ('Namitha I Love You', 'Jayanthi', ['Tumse Achha Kaun Hai', 'Thotalo Pilla Kotalo Rani'], '1945', 'Reparto', 'Jayanti'), ('Namitha I Love You', 'Kavitha', ['Arjun Reddy', 'Kaadhalan'], 'N/A', 'Reparto', 'N/A'), ('Namitha I Love You', 'Tennis Krishna', ['Uppi 2', 'Veera Madakari'], 'N/A', 'Reparto, Música, Banda sonora', 'N/A'), ('Namitha I Love You', 'Dingri Nagaraj', ['Murder', 'Parashuram'], 'N/A', 'Reparto', 'N/A'), ('Namitha I Love You', 'Namitha', ['Billa', 'Billa'], '1981', 'Reparto', '1 nominación'), ('Namitha I Love You', 'Gollahalli Shivprasad', ['Mathad Mathadu Mallige', 'Namitha I Love You'], 'N/A', 'Reparto, Guion, Música', 'N/A')]
# Datos de los actores:
# [('Panchamrutha', 'Ramya Barna', ['Hudugaru', 'Lifeu Ishtene'], 'N/A', 'Reparto', 'N/A'), ('Panchamrutha', 'Sudha Belawadi', ['ACT 1978', 'Bachchan'], 'N/A', 'Reparto', 'N/A'), ('Panchamrutha', 'Devaraj', ['Salaar. Part 1 - Ceasefire', 'Ranna'], 'N/A', 'Reparto', '1 nominación'), ('Panchamrutha', 'Pooja Gandhi', ['Krishna', 'Accident'], '1983', 'Reparto, Música, Producción', 'N/A'), ('Panchamrutha', 'Narahalli Jnanesh', ['School Master', 'Eddelu Manjunatha'], 'N/A', 'Edición, Reparto', 'N/A'), ('Panchamrutha', 'Srinagar Kitty', ['Sanju Weds Geetha', 'Gowli'], 'N/A', 'Reparto, Producción', 'N/A'), ('Panchamrutha', 'Achyuth Kumar', ['Kantara', 'K.G.F: Chapter 1'], '1966', 'Reparto', '5 premios y 5 nominaciones'), ('Panchamrutha', 'Raghu Mukherjee', ['Kaafi Thota', 'Savaari'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Manasina Maathu', 'Avinash', ['Aaptharakshaka', '7aum Arivu'], 'N/A', 'Reparto, Efectos visuales, Cámara y electricidad', '1 premio y 1 nominación'), ('Manasina Maathu', 'Mohan Juneja', ['K.G.F: Chapter 2', 'K.G.F: Chapter 1'], '2021', 'Reparto, Guion', 'N/A'), ('Manasina Maathu', 'Sadhu Kokila', ['Mr. Theertha', 'Mr. And Mrs. Ramchari'], '1966', 'Reparto, Composición, Música', '2 premios y 5 nominaciones'), ('Manasina Maathu', 'Sharath Lohitashwa', ['Aa Dinagalu', 'Saarathi'], '1972', 'Reparto', 'N/A'), ('Manasina Maathu', 'Lohith', ['Maharshi', 'Manasina Maathu'], 'N/A', 'Reparto', 'N/A'), ('Manasina Maathu', 'Ajay Rao', ['Krishna Leela', 'Krishnan Marriage Story'], '1980', 'Reparto, Animación', '5 nominaciones'), ('Manasina Maathu', 'Aindrita Ray', ['Bhajarangi', 'Veera Parampare'], '1985', 'Reparto', '1 premio y 4 nominaciones'), ('Manasina Maathu', 'Satyajith', ['Maanikya', 'Sye'], '1949', 'Reparto', 'Sathyajith')]
# Datos de los actores:
# ...
# Datos de los actores:
# [('Fausto', 'Johannes Zeiler', ['CopStories', 'Wackersdorf'], '1970', 'Reparto', '3 nominaciones'), ('Fausto', 'Anton Adasinsky', ['Fausto', 'Süd. Grenze'], '1959', 'Reparto, Dirección, Guion', '2 premios y 1 nominación'), ('Fausto', 'Isolda Dychauk', ['Fausto', 'Borgia'], '1993', 'Reparto, Producción, Guion', '1 premio y 1 nominación'), ('Fausto', 'Georg Friedrich', ['Great Freedom (Gran libertad)', 'Wilde Maus'], '1966', 'Reparto, Banda sonora', '7 premios y 15 nominaciones'), ('Fausto', 'Hanna Schygulla', ['El matrimonio de María Braun', 'Al otro lado'], '1943', 'Reparto, Dirección, Guion', '27 premios y 12 nominaciones'), ('Fausto', 'Antje Lewald', ['Die Camper', 'Por los niños'], '1960', 'Reparto', 'Antje Lehwald'), ('Fausto', 'Florian Brückner', ['Los tres mosqueteros', 'Was weg is, is weg'], '1984', 'Reparto', 'N/A'), ('Fausto', 'Maxim Mehmet', ['El Barón Rojo', 'Hijos del Tercer Reich'], '1975', 'Reparto, Cámara y electricidad, Localización', '1 premio')]
# Datos de los actores:
# [('One Kine Day', 'Ryan Greer', ['One Kine Day'], 'N/A', 'Reparto', 'N/A'), ('One Kine Day', 'Christa B. Allen', ['El sueño de mi vida', 'Revenge'], '1991', 'Reparto, Banda sonora', '1 premio'), ('One Kine Day', 'Julia Nickson', ['Dejadme ser libre', 'Noble House'], '1958', 'Reparto, Equipos adicionales', '2 nominaciones'), ('One Kine Day', 'Steve Parker', ['One Kine Day'], 'N/A', 'Reparto', 'N/A'), ('One Kine Day', 'Noah Parker', ['One Kine Day', 'Biting Off More Than You Can Chew'], 'N/A', 'Reparto', 'N/A'), ('One Kine Day', 'Nalu Boersma', ['One Kine Day'], 'N/A', 'Reparto', 'N/A'), ('One Kine Day', 'Sean Reilly', ['One Kine Day'], 'N/A', 'Reparto', 'N/A'), ('One Kine Day', 'Auriel P. Rickard', ['Jacquemus: Spring/Summer 2022', 'One Kine Day'], 'N/A', 'Reparto, Casting, Producción', 'N/A')]
# Datos de los actores:
# [('Perfect sense', 'Eva Green', ['Casino Royale', 'Penny Dreadful'], '1980', 'Reparto, Producción, Banda sonora', '5 premios y 23 nominaciones en total'), ('Perfect sense', 'Lauren Tempany', ['Perfect sense'], 'N/A', 'Reparto', 'N/A'), ('Perfect sense', 'Ewan McGregor', ['Moulin Rouge', 'Trainspotting'], '1971', 'Reparto, Producción, Guion', '36 premios y 77 nominaciones en total'), ('Perfect sense', 'Connie Nielsen', ['Gladiator (El gladiador)', 'Retratos de una obsesión'], '1965', 'Reparto, Producción, Guion', '5 premios y 10 nominaciones'), ('Perfect sense', 'Denis Lawson', ['La guerra de las galaxias', 'El retorno del jedi'], '1947', 'Reparto, Dirección, Guion', '4 nominaciones en total'), ('Perfect sense', 'Stephen Dillane', ['Las horas', 'Juego de tronos'], '1957', 'Reparto, Banda sonora', '7 premios y 10 nominaciones en total'), ('Perfect sense', 'Shabana Akhtar Bakhsh', ['Perfect sense', 'Un beso'], '1981', 'Reparto', 'Shabana Bakhsh'), ('Perfect sense', 'Caroline Paterson', ['Perfect sense', 'Tinsel Town'], '1965', 'Reparto, Dirección, Guion', 'N/A')]
# Datos de los actores:
# [('Arzanda', 'Yayra Abdullaeva', ['Sluchay v pustyne', 'Bay i batrak'], '1930', 'Reparto', 'Ya. Abdulayeva'), ('Arzanda', 'Umid Iskandarov', ["Sarobga yo'l", 'Ishq va anduh'], 'N/A', 'Reparto, Dirección, Guion', 'N/A'), ('Arzanda', 'Samandar Khamrakulov', ['Arzanda', 'Muhabbat Sinovlari'], 'N/A', 'Reparto, Dirección, Guion', 'N/A'), ('Arzanda', 'Matyoqub Matchanov', ['Sohni Mahiwal', 'Snayper'], '1956', 'Reparto', 'N/A'), ('Arzanda', 'Saida Rametova', ['Arslon izidan', 'Qudajonlar'], 'N/A', 'Reparto, Producción, Guion', 'N/A'), ('Arzanda', 'Takhir Saidov', ['18 kvadrat', 'Hayot'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('A Beautiful Belly', 'Chris Worley', ['Going Up (a webseries)', 'A Beautiful Belly'], 'N/A', 'Reparto, Guion, Producción', '1,82 m'), ('A Beautiful Belly', 'Lauren Brown', ['The Sacred', 'Bloody 27'], 'N/A', 'Reparto', 'N/A'), ('A Beautiful Belly', 'Michele Simms', ['Sex Drive', 'Red Tide'], '1977', 'Reparto, Guion', 'N/A'), ('A Beautiful Belly', 'John William Wright', ['Pretty Little Victim', 'Dating a Killer'], 'N/A', 'Reparto, Dirección de la segunda unidad o asistencia a dirección, Cámara y electricidad', 'Duke McCallister'), ('A Beautiful Belly', 'Amy LoCicero', ['Divina de la muerte', 'Big Mike'], 'N/A', 'Reparto', 'N/A'), ('A Beautiful Belly', 'Peyton Lee', ['Crónicas vampíricas', 'Divina de la muerte'], 'N/A', 'Reparto', 'N/A'), ('A Beautiful Belly', 'Raymond D. Sweet', ['Unidad de élite', 'The Exile'], 'N/A', 'Reparto, Equipos adicionales, Cámara y electricidad', 'Raymond Sweet'), ('A Beautiful Belly', 'Randy Molnar', ['The Tenant', 'Dasavatharam'], 'N/A', 'Reparto, Producción, Localización', '1 nominación')]
# Datos de los actores:
# [('Un pedacito de cielo', 'Kate Hudson', ['Casi famosos', 'Cómo perder a un chico en 10 días'], '1979', 'Reparto, Producción, Dirección', '18 premios y 39 nominaciones en total'), ('Un pedacito de cielo', 'Gael García Bernal', ['Mozart in the Jungle', 'Diarios de motocicleta'], '1978', 'Reparto, Producción, Guion', '39 premios y 52 nominaciones en total'), ('Un pedacito de cielo', 'Kathy Bates', ['Misery', 'Eclipse total (Dolores Claiborne)'], '1948', 'Reparto, Dirección, Producción', '38 premios y 99 nominaciones en total'), ('Un pedacito de cielo', 'Lucy Punch', ['Into the Woods', 'Bad Teacher'], '1977', 'Reparto, Guion, Producción', '3 premios y 7 nominaciones'), ('Un pedacito de cielo', 'Romany Malco', ['Weeds', 'Virgen a los 40'], '1968', 'Reparto, Dirección, Guion', '6 premios y 8 nominaciones'), ('Un pedacito de cielo', 'Rosemarie DeWitt', ['La boda de Rachel', 'El amigo de mi hermana'], '1971', 'Reparto, Equipos adicionales', '9 premios y 25 nominaciones'), ('Un pedacito de cielo', 'Whoopi Goldberg', ['Ghost (Más allá del amor)', 'Sister Act (Una monja de cuidado)'], '1955', 'Reparto, Producción, Guion', 'N/A'), ('Un pedacito de cielo', 'Treat Williams', ['Deep Rising: El misterio de las profundidades', 'Hair'], '1951', 'Reparto, Dirección, Producción', '1 premio y 14 nominaciones en total')]
# Datos de los actores:
# [('Un lugar donde quedarse (This Must Be the Place)', 'Sean Penn', ['Mystic River', '21 gramos'], '1960', 'Reparto, Producción, Dirección', 'N/A'), ('Un lugar donde quedarse (This Must Be the Place)', 'Olwen Fouéré', ['El hombre del norte', 'La matanza de Texas'], 'marzo', 'Reparto, Guion, Dirección', '2 premios y 2 nominaciones'), ('Un lugar donde quedarse (This Must Be the Place)', 'Eve Hewson', ['Robin Hood: Forajido, héroe, leyenda', 'El puente de los espías'], '1991', 'Reparto, Banda sonora', '3 premios y 8 nominaciones'), ('Un lugar donde quedarse (This Must Be the Place)', 'Johnny Ward', ['Un lugar donde quedarse (This Must Be the Place)', 'Dollhouse'], 'N/A', 'Reparto', '1 premio'), ('Un lugar donde quedarse (This Must Be the Place)', 'Sam Keeley', ['Joe vs. Carole', 'Kin'], '1990', 'Reparto', '1 premio y 1 nominación'), ('Un lugar donde quedarse (This Must Be the Place)', "Danielle O'Brien", ['Un lugar donde quedarse (This Must Be the Place)', 'Tinderface'], 'N/A', 'Reparto', 'N/A'), ('Un lugar donde quedarse (This Must Be the Place)', "Margaret O'Reilly", ['Un lugar donde quedarse (This Must Be the Place)'], 'N/A', 'Reparto', 'N/A'), ('Un lugar donde quedarse (This Must Be the Place)', 'Frances McDormand', ['Tres anuncios en las afueras', 'Fargo'], '1957', 'Reparto, Producción, Banda sonora', '143 premios y 140 nominaciones en total')]
# Datos de los actores:
# [('Martha Marcy May Marlene', 'Elizabeth Olsen', ['Martha Marcy May Marlene', 'Doctor Strange en el multiverso de la locura'], '1989', 'Reparto, Producción, Banda sonora', '23 premios y 64 nominaciones en total'), ('Martha Marcy May Marlene', 'Christopher Abbott', ['Llega de noche', 'Possessor Uncut'], '1986', 'Reparto, Producción, Banda sonora', '5 premios y 27 nominaciones'), ('Martha Marcy May Marlene', 'Brady Corbet', ['Funny Games', 'Melancolía'], '1988', 'Reparto, Producción, Dirección', '9 premios y 18 nominaciones'), ('Martha Marcy May Marlene', 'Hugh Dancy', ['Hannibal', 'Adam'], '1975', 'Reparto, Producción, Banda sonora', '2 premios y 15 nominaciones en total'), ('Martha Marcy May Marlene', 'Maria Dizzia', ['Martha Marcy May Marlene', 'Mientras seamos jóvenes'], '1974', 'Reparto', '1 premio y 1 nominación'), ('Martha Marcy May Marlene', 'Julia Garner', ['The Assistant', 'Ozark'], '1994', 'Reparto, Producción', 'N/A'), ('Martha Marcy May Marlene', 'John Hawkes', ['Las sesiones', "Winter's Bone"], '1959', 'Reparto, Música, Producción', '18 premios y 63 nominaciones en total'), ('Martha Marcy May Marlene', 'Louisa Krause', ['The Dive', 'Billions'], '1986', 'Reparto, Cámara y electricidad, Banda sonora', '3 premios y 2 nominaciones')]
# No se encontró el actor número 5
# No se encontró el actor número 6
# Datos de los actores:
# [('Hahithalfut', 'Rotem Keinan', ['Fauda', 'Big bad wolves'], '1979', 'Reparto', 'N/A'), ('Hahithalfut', 'Sharon Tal', ['Noa', 'Snapshot'], 'N/A', 'Reparto', '1 premio y 2 nominaciones'), ('Hahithalfut', 'Dov Navon', ['Kupa Rashit', 'Zohi Sdom'], '1961', 'Reparto', '3 nominaciones'), ('Hahithalfut', 'Shirili Deshe', ['Yaldey Bet HaEtz', 'Youth'], '1968', 'Dirección, Guion, Reparto', 'N/A'), ('Hahithalfut', 'John Hawkes', ['Las sesiones', "Winter's Bone"], '1959', 'Reparto, Música, Producción', '18 premios y 63 nominaciones en total'), ('Hahithalfut', 'Louisa Krause', ['The Dive', 'Billions'], '1986', 'Reparto, Cámara y electricidad, Banda sonora', '3 premios y 2 nominaciones')]
# Datos de los actores:
# [('La pesca del salmón en Yemen', 'Amr Waked', ['Lucy', 'Geostorm'], '1973', 'Reparto, Producción, Dirección', '9 premios y 1 nominación'), ('La pesca del salmón en Yemen', 'Emily Blunt', ['Al filo del mañana', 'El diablo viste de Prada'], '1983', 'Reparto, Producción, Equipos adicionales', 'N/A'), ('La pesca del salmón en Yemen', 'Catherine Steadman', ['The Rook', 'Downton Abbey'], 'N/A', 'Reparto, Guion, Producción', '1 nominación'), ('La pesca del salmón en Yemen', 'Tom Mison', ['Sleepy Hollow', 'Persiguiendo a Jane Austen'], '1982', 'Reparto, Guion, Banda sonora', '4 nominaciones'), ('La pesca del salmón en Yemen', 'Ewan McGregor', ['Moulin Rouge', 'Trainspotting'], '1971', 'Reparto, Producción, Guion', '36 premios y 77 nominaciones en total'), ('La pesca del salmón en Yemen', 'Rachael Stirling', ['Blancanieves y la leyenda del cazador', 'La reina Victoria'], '1977', 'Reparto, Banda sonora', '2 premios y 1 nominación'), ('La pesca del salmón en Yemen', 'Kristin Scott Thomas', ['Gosford Park', 'El paciente inglés'], '1960', 'Reparto, Dirección, Guion', '29 premios y 54 nominaciones en total'), ('La pesca del salmón en Yemen', 'Tom Beard', ['La pesca del salmón en Yemen', 'Más allá de la vida'], '1965', 'Reparto', '(un cáncer de páncreas)')]
# Datos de los actores:
# [('The Jonestown Defense', 'Dennis Ostermaier', ['The Jonestown Defense', 'Red Dead Revolver'], 'N/A', 'Reparto, Producción, Guion', 'Dennis Ostermair'), ('The Jonestown Defense', 'Robert Stevens', ['Nightfall', 'The Jonestown Defense'], 'N/A', 'Reparto', 'N/A'), ('The Jonestown Defense', 'Michael Michaelessi', ['Las vírgenes suicidas', 'The Jonestown Defense'], 'N/A', 'Reparto', 'N/A'), ('The Jonestown Defense', 'Amy Seimetz', ['Upstream Color', "Sun Don't Shine"], '1981', 'Reparto, Guion, Producción', '6 premios y 20 nominaciones'), ('The Jonestown Defense', 'Mary Bronstein', ['Yeast', "If I Had Legs I'd Kick You"], '1979', 'Reparto, Guion, Dirección', 'Mary Wall'), ('The Jonestown Defense', 'Matt Timms', ['How I Know You', 'Up with Me'], 'N/A', 'Reparto, Dirección de fotografía y cámara, Cámara y electricidad', 'N/A'), ('The Jonestown Defense', 'April Barton', ['The Jonestown Defense'], 'N/A', 'Reparto', 'N/A'), ('The Jonestown Defense', 'Michael Weimann', ['The Jonestown Defense'], 'N/A', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Biester müssen sterben', 'Nikola Kastner', ['Homeland', 'Bienvenida al pueblo, doctora'], '1983', 'Reparto', '1 nominación'), ('Biester müssen sterben', 'Florian Bartholomäi', ['En el lugar del crimen', 'Ruby, la última viajera del tiempo'], '1987', 'Reparto, Banda sonora', '5 premios y 2 nominaciones'), ('Biester müssen sterben', 'Sinta Tamsjadi', ['Biester müssen sterben', 'En el lugar del crimen'], '1962', 'Reparto, Guion', 'N/A'), ('Biester müssen sterben', 'Oana Solomon', ['Gipsy Queen', 'Zoom'], '1966', 'Reparto', 'Oona Solomon'), ('Biester müssen sterben', 'Philipp Denzel', ['Biester müssen sterben', 'Was es ist'], '1977', 'Reparto', 'N/A')]
# Datos de los actores:
# [('Taj', 'Mahesh Jadu', ['The Witcher', 'Marco Polo'], '1982', 'Reparto, Producción, Guion', '1 premio'), ('Taj', 'Coco-Jacinta Cherian', ['Taj', 'Vecinos'], 'N/A', 'Reparto', 'Coco Cherian'), ('Taj', 'Sachin Joab', ['Spreadsheet', 'Lion'], 'N/A', 'Reparto', '1 premio y 1 nominación'), ('Taj', "Natalie O'Donnell", ['Mi vida en ruinas', 'Lowdown'], 'N/A', 'Reparto', 'N/A'), ('Taj', 'Rodney Van Der Wall', ['Fever', 'Taj'], 'N/A', 'Reparto', 'N/A'), ('Taj', 'Mark Mitchell', ['The Comedy Company', 'Farscape'], '1954', 'Reparto', '2 nominaciones'), ('Taj', 'Nicholas Bell', ['Power Rangers: La película', 'Dark City'], '1958', 'Reparto', '2 nominaciones'), ('Taj', 'Davini Malcolm', ['Love, Tea & Epiphany', 'Law of the Land'], 'N/A', 'Reparto, Producción, Dirección', 'N/A')]
# Datos de los actores:
# [('Pie de página', 'Shlomo Bar-Aba', ['Pie de página', 'Sheifa lehaim'], '1950', 'Reparto, Guion', '1 premio y 1 nominación'), ('Pie de página', 'Lior Ashkenazi', ['Pie de página', 'Big bad wolves'], 'diciembre', 'Reparto, Dirección', '6 premios y 8 nominaciones'), ('Pie de página', 'Aliza Rosen', ['La fiesta de despedida', 'Ha-Yanshouf'], '1939', 'Reparto, Equipos adicionales', '1 premio y 1 nominación'), ('Pie de página', 'Alma Zack', ['BeTipul', 'Zohi Sdom'], '1970', 'Reparto, Guion', '1 premio y 4 nominaciones'), ('Pie de página', 'Micah Lewensohn', ['Pie de página', 'Dig'], 'N/A', 'Reparto', 'N/A'), ('Pie de página', 'Nevo Kimchi', ['Beaufort', 'Laces'], '1965', 'Reparto', '1 nominación'), ('Pie de página', 'Yuval Scharf', ['McMafia', 'The Beauty Queen of Jerusalem'], '1985', 'Reparto', '3 nominaciones'), ('Pie de página', 'Daniel Markovich', ['Pie de página', 'A Letter from the Past'], 'N/A', 'Reparto', 'N/A')]
# No se encontró el actor número 1
# Datos de los actores:
# []
# Datos de los actores:
# [('Leave', 'Rick Gomez', ['Silo', 'Hermanos de sangre'], 'junio', 'Reparto, Guion, Dirección', '3 premios y 1 nominación'), ('Leave', 'Frank John Hughes', ['Hermanos de sangre', 'Atrápame si puedes'], 'noviembre', 'Reparto, Guion, Producción', '1 premio'), ('Leave', 'Vinessa Shaw', ['El tren de las 3:10', 'El retorno de las brujas'], '1976', 'Reparto, Dirección, Producción', '10 nominaciones'), ('Leave', 'Ron Livingston', ['Expediente Warren: The Conjuring', 'Trabajo basura'], '1967', 'Reparto, Cámara y electricidad, Producción', '3 nominaciones'), ('Leave', 'Bryan Cranston', ['Breaking Bad', 'Malcolm'], '1956', 'Reparto, Producción, Guion', '59 premios y 106 nominaciones en total'), ('Leave', 'M.C. Gainey', ['Club Desmadre', 'Cerdos salvajes: Con un par... de ruedas'], '1948', 'Reparto, Producción', '1 nominación'), ('Leave', 'Freddie Joe Farnsworth', ['Capitán América: El primer vengador', 'Guerra mundial Z'], '1968', 'Especialistas, Equipos adicionales, Reparto', 'N/A'), ('Leave', 'Brandon Waters', ['Scrubs', 'El mentalista'], '1997', 'Reparto', 'N/A')]

# %%
#Pasamos a dataframe la lista de listas, definiendo el nombre de sus columnas
df_extraccion = df = pd.DataFrame(extraccion, columns=["nombre_peli", "nombre_actxr", "conocido_por", "year_nacimiento", "profesiones_string", "premios"]) #creación del dataframe

# %%
#Visualizamos el Dataframe
df_extraccion
# Out:
#      nombre_peli            nombre_actxr  \
# 0     Redemption             Derek Burke
# 1     Redemption              July Smith
# 2     Redemption           Adam Chambers
# 3     Redemption          Shaina Vorspan
# 4     Redemption             Marco Neves
# ...          ...                     ...
# 1034       Leave          Ron Livingston
# 1035       Leave          Bryan Cranston
# 1036       Leave             M.C. Gainey
# 1037       Leave  Freddie Joe Farnsworth
# 1038       Leave          Brandon Waters
#
#                                            conocido_por year_nacimiento  \
# 0                               [Redemption, Reversion]             N/A
# 1                     [Redemption, A Fire in a Dovecot]             N/A
# 2            [Skylar contra el monstruo, I <3 Vampires]            1983
# 3                              [Dollface, Morir de pie]           junio
# 4                  [4 Horsemen: Apocalypse, Redemption]             N/A
# ...                                                 ...             ...
# 1034  [Expediente Warren: The Conjuring, Trabajo bas...            1967
# 1035                            [Breaking Bad, Malcolm]            1956
# 1036  [Club Desmadre, Cerdos salvajes: Con un par......            1948
# 1037  [Capitán América: El primer vengador, Guerra m...            1968
# 1038                            [Scrubs, El mentalista]            1997
#
#                                profesiones_string  \
# 0                                         Reparto
# 1                                         Reparto
# 2                  Reparto, Dirección, Producción
# 3                       Reparto, Guion, Dirección
# 4                    Reparto, Equipos adicionales
# ...                                           ...
# 1034   Reparto, Cámara y electricidad, Producción
# 1035                   Reparto, Producción, Guion
# 1036                          Reparto, Producción
# 1037  Especialistas, Equipos adicionales, Reparto
# 1038                                      Reparto
#
#                                      premios
# 0                                        N/A
# 1                                        N/A
# 2                 3 premios y 2 nominaciones
# 3                    1 premio y 1 nominación
# 4                                     1,76 m
# ...                                      ...
# 1034                          3 nominaciones
# 1035  59 premios y 106 nominaciones en total
# 1036                            1 nominación
# 1037                                     N/A
# 1038                                     N/A
#
# [1039 rows x 6 columns]

# %%
#Lo guardamos pasándolo a csv
df_extraccion.to_csv("actorxs_datos.csv")
